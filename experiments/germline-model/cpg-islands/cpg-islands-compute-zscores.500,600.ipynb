# %%
import logging 

logging.basicConfig(
  format = '%(asctime)s %(message)s',
  level=logging.INFO,
  datefmt='%Y-%m-%d %H:%M:%S'
)

# %%
import pyranges as pr

CONSTRAINT_TOOLS_DATA = '/scratch/ucgd/lustre-work/quinlan/data-shared/constraint-tools'
cpg_islands_path = f'{CONSTRAINT_TOOLS_DATA}/cpg-islands/grch38/cpg-islands.sorted.bed.gz'

# https://biocore-ntnu.github.io/pyranges/loadingcreating-pyranges.html
cpg_islands = pr.read_bed(cpg_islands_path)

cpg_islands.columns = ['Chromosome', 'Start', 'End', 'Name', 'Length', 'cpgNum', 'gcNum', 'perCpg', 'perGc', 'obsExp']
cpg_islands
# Out:
# +--------------+-----------+-----------+------------+-----------+--------------+-----------+-------------+-------------+-------------+
# | Chromosome   | Start     | End       | Name       | Length    | cpgNum       | gcNum     | perCpg      | perGc       | obsExp      |
# | (category)   | (int32)   | (int32)   | (object)   | (int64)   | (category)   | (int64)   | (float64)   | (float64)   | (float64)   |
# |--------------+-----------+-----------+------------+-----------+--------------+-----------+-------------+-------------+-------------|
# | chr1         | 28735     | 29737     | CpG: 111   | 1002      | 111          | 731       | 22.2        | 73.0        | 0.85        |
# | chr1         | 135124    | 135563    | CpG: 30    | 439       | 30           | 295       | 13.7        | 67.2        | 0.64        |
# | chr1         | 199251    | 200121    | CpG: 104   | 870       | 104          | 643       | 23.9        | 73.9        | 0.89        |
# | chr1         | 368792    | 370063    | CpG: 99    | 1271      | 99           | 777       | 15.6        | 61.1        | 0.84        |
# | ...          | ...       | ...       | ...        | ...       | ...          | ...       | ...         | ...         | ...         |
# | chrY         | 26409388  | 26409785  | CpG: 32    | 397       | 32           | 252       | 16.1        | 63.5        | 0.82        |
# | chrY         | 26627168  | 26627397  | CpG: 25    | 229       | 25           | 172       | 21.8        | 75.1        | 0.78        |
# | chrY         | 57067645  | 57068034  | CpG: 36    | 389       | 36           | 257       | 18.5        | 66.1        | 0.85        |
# | chrY         | 57203115  | 57203423  | CpG: 29    | 308       | 29           | 190       | 18.8        | 61.7        | 0.99        |
# +--------------+-----------+-----------+------------+-----------+--------------+-----------+-------------+-------------+-------------+
# Unstranded PyRanges object has 27,949 rows and 10 columns from 24 chromosomes.
# For printing, the PyRanges was sorted on Chromosome.

# %%
import sys
sys.path.append('/scratch/ucgd/lustre-work/quinlan/u6018199/constraint-tools/utilities')

from read_model import read_model 

model = read_model('/scratch/ucgd/lustre-work/quinlan/u6018199/constraint-tools/dist/model-germline-grch38.json')

# https://biocore-ntnu.github.io/pyranges/loadingcreating-pyranges.html
neutral_regions = pr.read_bed(model['neutralRegions'])

neutral_regions
# Out:
# +--------------+-----------+-----------+
# | Chromosome   | Start     | End       |
# | (category)   | (int32)   | (int32)   |
# |--------------+-----------+-----------|
# | chr1         | 14653     | 14905     |
# | chr1         | 15354     | 15772     |
# | chr1         | 16125     | 16607     |
# | chr1         | 17055     | 17171     |
# | ...          | ...       | ...       |
# | chr22        | 50796386  | 50796692  |
# | chr22        | 50796780  | 50796942  |
# | chr22        | 50797586  | 50797812  |
# | chr22        | 50798276  | 50798655  |
# +--------------+-----------+-----------+
# Unstranded PyRanges object has 1,649,459 rows and 3 columns from 22 chromosomes.
# For printing, the PyRanges was sorted on Chromosome.

# %%
cpg_islands.cpg_island_id = cpg_islands.df.index.values

def compute_cpg_island_region(row):
  return f'{row["Chromosome"]}:{row["Start"]}-{row["End"]}'
cpg_islands.cpg_island_region = cpg_islands.df.apply(compute_cpg_island_region, axis=1)

cpg_islands
# Out:
# +--------------+-----------+-----------+------------+-----------+--------------+-----------+-------------+-------------+-------+
# | Chromosome   | Start     | End       | Name       | Length    | cpgNum       | gcNum     | perCpg      | perGc       | +3    |
# | (category)   | (int32)   | (int32)   | (object)   | (int64)   | (category)   | (int64)   | (float64)   | (float64)   | ...   |
# |--------------+-----------+-----------+------------+-----------+--------------+-----------+-------------+-------------+-------|
# | chr1         | 28735     | 29737     | CpG: 111   | 1002      | 111          | 731       | 22.2        | 73.0        | ...   |
# | chr1         | 135124    | 135563    | CpG: 30    | 439       | 30           | 295       | 13.7        | 67.2        | ...   |
# | chr1         | 199251    | 200121    | CpG: 104   | 870       | 104          | 643       | 23.9        | 73.9        | ...   |
# | chr1         | 368792    | 370063    | CpG: 99    | 1271      | 99           | 777       | 15.6        | 61.1        | ...   |
# | ...          | ...       | ...       | ...        | ...       | ...          | ...       | ...         | ...         | ...   |
# | chrY         | 26409388  | 26409785  | CpG: 32    | 397       | 32           | 252       | 16.1        | 63.5        | ...   |
# | chrY         | 26627168  | 26627397  | CpG: 25    | 229       | 25           | 172       | 21.8        | 75.1        | ...   |
# | chrY         | 57067645  | 57068034  | CpG: 36    | 389       | 36           | 257       | 18.5        | 66.1        | ...   |
# | chrY         | 57203115  | 57203423  | CpG: 29    | 308       | 29           | 190       | 18.8        | 61.7        | ...   |
# +--------------+-----------+-----------+------------+-----------+--------------+-----------+-------------+-------------+-------+
# Unstranded PyRanges object has 27,949 rows and 12 columns from 24 chromosomes.
# For printing, the PyRanges was sorted on Chromosome.
# 3 hidden columns: obsExp, cpg_island_id, cpg_island_region

# %%
# https://pyranges.readthedocs.io/en/latest/autoapi/pyranges/pyranges/index.html?highlight=intersect#pyranges.pyranges.PyRanges.overlap

cpg_islands_that_overlap_neutral_regions = cpg_islands.overlap(neutral_regions).df
cpg_islands_that_overlap_neutral_regions
# Out:
#       Chromosome     Start       End      Name  Length cpgNum  gcNum  perCpg  \
# 0           chr1    135124    135563   CpG: 30     439     30    295    13.7
# 1           chr1    778604    779167   CpG: 60     563     60    385    21.3
# 2           chr1    869818    870248   CpG: 50     430     50    316    23.3
# 3           chr1    904314    905239  CpG: 119     925    119    693    25.7
# 4           chr1    908919    910503  CpG: 154    1584    154   1106    19.4
# ...          ...       ...       ...       ...     ...    ...    ...     ...
# 21422      chr22  50697242  50697698   CpG: 56     456     56    327    24.6
# 21423      chr22  50704374  50704880   CpG: 38     506     38    328    15.0
# 21424      chr22  50710877  50711294   CpG: 41     417     41    267    19.7
# 21425      chr22  50719958  50721632  CpG: 180    1674    180   1209    21.5
# 21426      chr22  50730599  50731304   CpG: 65     705     65    416    18.4
#
#        perGc  obsExp  cpg_island_id        cpg_island_region
# 0       67.2    0.64              1       chr1:135124-135563
# 1       68.4    0.92              8       chr1:778604-779167
# 2       73.5    0.87             12       chr1:869818-870248
# 3       74.9    0.92             13       chr1:904314-905239
# 4       69.8    0.82             14       chr1:908919-910503
# ...      ...     ...            ...                      ...
# 21422   71.7    0.96          26860  chr22:50697242-50697698
# 21423   64.8    0.72          26861  chr22:50704374-50704880
# 21424   64.0    1.01          26862  chr22:50710877-50711294
# 21425   72.2    0.84          26863  chr22:50719958-50721632
# 21426   59.0    1.08          26864  chr22:50730599-50731304
#
# [21427 rows x 12 columns]

# %%
# https://pyranges.readthedocs.io/en/latest/autoapi/pyranges/pyranges/index.html?highlight=intersect#pyranges.pyranges.PyRanges.intersect

neutral_regions_within_cpg_islands = cpg_islands.intersect(neutral_regions).df[['Start', 'End', 'cpg_island_id']]
neutral_regions_within_cpg_islands
# Out:
#           Start       End  cpg_island_id
# 0        135124    135141              1
# 1        779092    779167              8
# 2        869818    870086             12
# 3        870201    870248             12
# 4        904314    904478             13
# ...         ...       ...            ...
# 35769  50710983  50711117          26862
# 35770  50711118  50711224          26862
# 35771  50711225  50711294          26862
# 35772  50719958  50720184          26863
# 35773  50730599  50730721          26864
#
# [35774 rows x 3 columns]

# %%
import pandas as pd

cpg_islands_with_neutral_regions = pd.merge(
  cpg_islands_that_overlap_neutral_regions, 
  neutral_regions_within_cpg_islands, 
  on='cpg_island_id', 
  how='inner'
)
cpg_islands_with_neutral_regions = cpg_islands_with_neutral_regions.rename(columns={
  "Start_x": "Start_cpg_island", 
  "End_x": "End_cpg_island",
  "Start_y": "Start_neutral_part", 
  "End_y": "End_neutral_part",
})
cpg_islands_with_neutral_regions
# Out:
#       Chromosome  Start_cpg_island  End_cpg_island      Name  Length cpgNum  \
# 0           chr1            135124          135563   CpG: 30     439     30
# 1           chr1            778604          779167   CpG: 60     563     60
# 2           chr1            869818          870248   CpG: 50     430     50
# 3           chr1            869818          870248   CpG: 50     430     50
# 4           chr1            904314          905239  CpG: 119     925    119
# ...          ...               ...             ...       ...     ...    ...
# 35769      chr22          50710877        50711294   CpG: 41     417     41
# 35770      chr22          50710877        50711294   CpG: 41     417     41
# 35771      chr22          50710877        50711294   CpG: 41     417     41
# 35772      chr22          50719958        50721632  CpG: 180    1674    180
# 35773      chr22          50730599        50731304   CpG: 65     705     65
#
#        gcNum  perCpg  perGc  obsExp  cpg_island_id        cpg_island_region  \
# 0        295    13.7   67.2    0.64              1       chr1:135124-135563
# 1        385    21.3   68.4    0.92              8       chr1:778604-779167
# 2        316    23.3   73.5    0.87             12       chr1:869818-870248
# 3        316    23.3   73.5    0.87             12       chr1:869818-870248
# 4        693    25.7   74.9    0.92             13       chr1:904314-905239
# ...      ...     ...    ...     ...            ...                      ...
# 35769    267    19.7   64.0    1.01          26862  chr22:50710877-50711294
# 35770    267    19.7   64.0    1.01          26862  chr22:50710877-50711294
# 35771    267    19.7   64.0    1.01          26862  chr22:50710877-50711294
# 35772   1209    21.5   72.2    0.84          26863  chr22:50719958-50721632
# 35773    416    18.4   59.0    1.08          26864  chr22:50730599-50731304
#
#        Start_neutral_part  End_neutral_part
# 0                  135124            135141
# 1                  779092            779167
# 2                  869818            870086
# 3                  870201            870248
# 4                  904314            904478
# ...                   ...               ...
# 35769            50710983          50711117
# 35770            50711118          50711224
# 35771            50711225          50711294
# 35772            50719958          50720184
# 35773            50730599          50730721
#
# [35774 rows x 14 columns]

# %%
def compute_neutral_part_length(row):
  return row['End_neutral_part'] - row['Start_neutral_part']

cpg_islands_with_neutral_regions['neutral_part_length'] = cpg_islands_with_neutral_regions.apply(compute_neutral_part_length, axis=1)
cpg_islands_with_neutral_regions
# Out:
#       Chromosome  Start_cpg_island  End_cpg_island      Name  Length cpgNum  \
# 0           chr1            135124          135563   CpG: 30     439     30
# 1           chr1            778604          779167   CpG: 60     563     60
# 2           chr1            869818          870248   CpG: 50     430     50
# 3           chr1            869818          870248   CpG: 50     430     50
# 4           chr1            904314          905239  CpG: 119     925    119
# ...          ...               ...             ...       ...     ...    ...
# 35769      chr22          50710877        50711294   CpG: 41     417     41
# 35770      chr22          50710877        50711294   CpG: 41     417     41
# 35771      chr22          50710877        50711294   CpG: 41     417     41
# 35772      chr22          50719958        50721632  CpG: 180    1674    180
# 35773      chr22          50730599        50731304   CpG: 65     705     65
#
#        gcNum  perCpg  perGc  obsExp  cpg_island_id        cpg_island_region  \
# 0        295    13.7   67.2    0.64              1       chr1:135124-135563
# 1        385    21.3   68.4    0.92              8       chr1:778604-779167
# 2        316    23.3   73.5    0.87             12       chr1:869818-870248
# 3        316    23.3   73.5    0.87             12       chr1:869818-870248
# 4        693    25.7   74.9    0.92             13       chr1:904314-905239
# ...      ...     ...    ...     ...            ...                      ...
# 35769    267    19.7   64.0    1.01          26862  chr22:50710877-50711294
# 35770    267    19.7   64.0    1.01          26862  chr22:50710877-50711294
# 35771    267    19.7   64.0    1.01          26862  chr22:50710877-50711294
# 35772   1209    21.5   72.2    0.84          26863  chr22:50719958-50721632
# 35773    416    18.4   59.0    1.08          26864  chr22:50730599-50731304
#
#        Start_neutral_part  End_neutral_part  neutral_part_length
# 0                  135124            135141                   17
# 1                  779092            779167                   75
# 2                  869818            870086                  268
# 3                  870201            870248                   47
# 4                  904314            904478                  164
# ...                   ...               ...                  ...
# 35769            50710983          50711117                  134
# 35770            50711118          50711224                  106
# 35771            50711225          50711294                   69
# 35772            50719958          50720184                  226
# 35773            50730599          50730721                  122
#
# [35774 rows x 15 columns]

# %%
cpg_islands_with_neutral_regions = cpg_islands_with_neutral_regions[['cpg_island_id', 'neutral_part_length']]
cpg_islands_with_neutral_regions
# Out:
#        cpg_island_id  neutral_part_length
# 0                  1                   17
# 1                  8                   75
# 2                 12                  268
# 3                 12                   47
# 4                 13                  164
# ...              ...                  ...
# 35769          26862                  134
# 35770          26862                  106
# 35771          26862                   69
# 35772          26863                  226
# 35773          26864                  122
#
# [35774 rows x 2 columns]

# %%
grouped_neutral_regions = cpg_islands_with_neutral_regions.groupby('cpg_island_id')

number_neutral_bases = grouped_neutral_regions['neutral_part_length'].sum().rename("number_neutral_bases")
number_neutral_bases
# Out:
# cpg_island_id
# 1         17
# 8         75
# 12       315
# 13       422
# 14       547
#         ...
# 26860    204
# 26861    382
# 26862    414
# 26863    226
# 26864    122
# Name: number_neutral_bases, Length: 21427, dtype: int64

# %%
number_neutral_parts = grouped_neutral_regions['neutral_part_length'].count().rename('number_neutral_parts')
number_neutral_parts
# Out:
# cpg_island_id
# 1        1
# 8        1
# 12       2
# 13       3
# 14       2
#         ..
# 26860    1
# 26861    2
# 26862    4
# 26863    1
# 26864    1
# Name: number_neutral_parts, Length: 21427, dtype: int64

# %%
cpg_islands = ( 
  cpg_islands.df
  .merge(number_neutral_bases, on='cpg_island_id', how='inner')
  .merge(number_neutral_parts, on='cpg_island_id', how='inner')
)

cpg_islands
# Out:
#       Chromosome     Start       End      Name  Length cpgNum  gcNum  perCpg  \
# 0           chr1    135124    135563   CpG: 30     439     30    295    13.7
# 1           chr1    778604    779167   CpG: 60     563     60    385    21.3
# 2           chr1    869818    870248   CpG: 50     430     50    316    23.3
# 3           chr1    904314    905239  CpG: 119     925    119    693    25.7
# 4           chr1    908919    910503  CpG: 154    1584    154   1106    19.4
# ...          ...       ...       ...       ...     ...    ...    ...     ...
# 21422      chr22  50697242  50697698   CpG: 56     456     56    327    24.6
# 21423      chr22  50704374  50704880   CpG: 38     506     38    328    15.0
# 21424      chr22  50710877  50711294   CpG: 41     417     41    267    19.7
# 21425      chr22  50719958  50721632  CpG: 180    1674    180   1209    21.5
# 21426      chr22  50730599  50731304   CpG: 65     705     65    416    18.4
#
#        perGc  obsExp  cpg_island_id        cpg_island_region  \
# 0       67.2    0.64              1       chr1:135124-135563
# 1       68.4    0.92              8       chr1:778604-779167
# 2       73.5    0.87             12       chr1:869818-870248
# 3       74.9    0.92             13       chr1:904314-905239
# 4       69.8    0.82             14       chr1:908919-910503
# ...      ...     ...            ...                      ...
# 21422   71.7    0.96          26860  chr22:50697242-50697698
# 21423   64.8    0.72          26861  chr22:50704374-50704880
# 21424   64.0    1.01          26862  chr22:50710877-50711294
# 21425   72.2    0.84          26863  chr22:50719958-50721632
# 21426   59.0    1.08          26864  chr22:50730599-50731304
#
#        number_neutral_bases  number_neutral_parts
# 0                        17                     1
# 1                        75                     1
# 2                       315                     2
# 3                       422                     3
# 4                       547                     2
# ...                     ...                   ...
# 21422                   204                     1
# 21423                   382                     2
# 21424                   414                     4
# 21425                   226                     1
# 21426                   122                     1
#
# [21427 rows x 14 columns]

# %%
# https://papermill.readthedocs.io/en/latest/usage-parameterize.html
number_neutral_bases_lower = None
number_neutral_bases_upper = None

# %%
# Parameters
number_neutral_bases_lower = 500
number_neutral_bases_upper = 600

# %%
# https://pandas.pydata.org/pandas-docs/stable/getting_started/intro_tutorials/03_subset_data.html#how-do-i-filter-specific-rows-from-a-dataframe
cpg_islands = cpg_islands[
    (cpg_islands.number_neutral_bases > number_neutral_bases_lower) & 
    (cpg_islands.number_neutral_bases < number_neutral_bases_upper) & 
    (cpg_islands.number_neutral_parts < 5)
]
cpg_islands
# Out:
#       Chromosome     Start       End      Name  Length cpgNum  gcNum  perCpg  \
# 4           chr1    908919    910503  CpG: 154    1584    154   1106    19.4
# 24          chr1   1059056   1059923   CpG: 96     867     96    610    22.1
# 30          chr1   1088695   1089234   CpG: 44     539     44    369    16.3
# 46          chr1   1246376   1247090   CpG: 87     714     87    527    24.4
# 82          chr1   1539582   1541289  CpG: 154    1707    154   1075    18.0
# ...          ...       ...       ...       ...     ...    ...    ...     ...
# 21285      chr22  46035765  46036329   CpG: 71     564     71    396    25.2
# 21318      chr22  46737757  46738686  CpG: 111     929    111    672    23.9
# 21374      chr22  50014627  50015708  CpG: 119    1081    119    803    22.0
# 21399      chr22  50306986  50307693   CpG: 94     707     94    553    26.6
# 21401      chr22  50342761  50343580   CpG: 79     819     79    542    19.3
#
#        perGc  obsExp  cpg_island_id        cpg_island_region  \
# 4       69.8    0.82             14       chr1:908919-910503
# 24      70.4    0.92             39     chr1:1059056-1059923
# 30      68.5    0.70             49     chr1:1088695-1089234
# 46      73.8    0.90             70     chr1:1246376-1247090
# 82      63.0    0.92            116     chr1:1539582-1541289
# ...      ...     ...            ...                      ...
# 21285   70.2    1.02          26689  chr22:46035765-46036329
# 21318   72.3    0.91          26726  chr22:46737757-46738686
# 21374   74.3    0.81          26795  chr22:50014627-50015708
# 21399   78.2    0.87          26829  chr22:50306986-50307693
# 21401   66.2    0.88          26832  chr22:50342761-50343580
#
#        number_neutral_bases  number_neutral_parts
# 4                       547                     2
# 24                      582                     1
# 30                      539                     1
# 46                      506                     2
# 82                      598                     1
# ...                     ...                   ...
# 21285                   518                     1
# 21318                   562                     2
# 21374                   530                     2
# 21399                   511                     1
# 21401                   543                     1
#
# [1428 rows x 14 columns]

# %%
#papermill_description=COMPUTE_ZSCORES

sys.path.append('/scratch/ucgd/lustre-work/quinlan/u6018199/constraint-tools/predict-constraint/germline-model')

import numpy as np 

from expected_observed_counts import compute_expected_observed_counts
from pack_unpack import pack

window_stride = 10 

def filter_and_average(xs): 
  if not xs: return None 
  else: return np.mean([x for x in xs if x])

def compute_neutral_zscores(row): 
  region = pack(row.Chromosome, row.Start, row.End)  
  expected_observed_counts = compute_expected_observed_counts(region, model, window_stride, log=False) 
  # https://www.dataquest.io/blog/settingwithcopywarning/
  with pd.option_context('mode.chained_assignment', None):
    row['N_bar_mean_neutral'] = filter_and_average(expected_observed_counts['NBarsNeutralRegions'])
    row['N_observeds_mean_neutral'] = filter_and_average(expected_observed_counts['NObservedsNeutralRegions'])
    row['K_bar_mean_neutral'] = filter_and_average(expected_observed_counts['KBarsNeutralRegions'])
    row['K_observeds_mean_neutral'] = filter_and_average(expected_observed_counts['KObservedsNeutralRegions'])
  return row 

# https://stackoverflow.com/a/34365537/6674256
from tqdm.auto import tqdm  # for notebooks
tqdm.pandas()
logging.info('Computing z-scores for cpg islands...')
cpg_islands_with_zscores = cpg_islands.progress_apply(compute_neutral_zscores, axis=1)
logging.info('...finished computing z-scores for cpg islands...')

cpg_islands_with_zscores.head()
# Out:
# 2022-06-01 16:28:50 Computing z-scores for cpg islands...
#   0%|          | 0/1428 [00:00<?, ?it/s]
# 2022-06-01 17:54:11 ...finished computing z-scores for cpg islands...
#    Chromosome    Start      End      Name  Length cpgNum  gcNum  perCpg  \
# 4        chr1   908919   910503  CpG: 154    1584    154   1106    19.4
# 24       chr1  1059056  1059923   CpG: 96     867     96    610    22.1
# 30       chr1  1088695  1089234   CpG: 44     539     44    369    16.3
# 46       chr1  1246376  1247090   CpG: 87     714     87    527    24.4
# 82       chr1  1539582  1541289  CpG: 154    1707    154   1075    18.0
#
#     perGc  obsExp  cpg_island_id     cpg_island_region  number_neutral_bases  \
# 4    69.8    0.82             14    chr1:908919-910503                   547
# 24   70.4    0.92             39  chr1:1059056-1059923                   582
# 30   68.5    0.70             49  chr1:1088695-1089234                   539
# 46   73.8    0.90             70  chr1:1246376-1247090                   506
# 82   63.0    0.92            116  chr1:1539582-1541289                   598
#
#     number_neutral_parts  N_bar_mean_neutral  N_observeds_mean_neutral  \
# 4                      2           -0.737377                 30.428571
# 24                     1           -2.250698                 24.653061
# 30                     1            0.277945                 31.795455
# 46                     2            0.290955                 37.000000
# 82                     1           -0.402780                 31.720000
#
#     K_bar_mean_neutral  K_observeds_mean_neutral
# 4            -0.180302                 14.542857
# 24            0.223145                 13.142857
# 30           -1.303639                 11.295455
# 46            0.178292                 18.354839
# 82            0.315946                 16.700000

# %%
cpg_islands_with_zscores_path = (
    f'{CONSTRAINT_TOOLS_DATA}/cpg-islands/grch38/'
    f'cpg-islands-with-zscores.{number_neutral_bases_lower}-{number_neutral_bases_upper}.bed'
)

cpg_islands_with_zscores.to_csv(cpg_islands_with_zscores_path, index=False, sep='\t')
