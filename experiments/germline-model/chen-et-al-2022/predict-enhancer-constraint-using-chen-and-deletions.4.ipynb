# %% [markdown]
# ## Get a set of regions known to be constrained, and a set of regions that are assumed to be constrained, together with their Chen scores

# %%
VERSION = 4

CONSTRAINT_TOOLS = '/scratch/ucgd/lustre-work/quinlan/u6018199/constraint-tools'
CONSTRAINT_TOOLS_DATA = '/scratch/ucgd/lustre-work/quinlan/data-shared/constraint-tools'

NUMBER_NEGATIVE_EXAMPLES = 1000
LABELED_REGIONS = f'labeled-regions.{VERSION}.bed'

import sys
sys.path.append(f'{CONSTRAINT_TOOLS}/utilities')

# %%
import pandas as pd

def read_disease_enhancers_intersect_chen_windows():
  # download-process-data/khurana/README.md
  df = pd.read_csv(
    f"{CONSTRAINT_TOOLS_DATA}/khurana/disease-enhancers-intersect-chen-windows.bed", 
    sep = '\t',
    names = [
        'chrom_enhancer', 'start_enhancer', 'end_enhancer', 
        'disease', 'enhancer_predicted_LoF_tolerance_prob', 'enhancer_predicted_LoF_tolerance_status', 
        'chrom_window', 'start_window', 'end_window', 
        'new_chen_score_window'
    ]
  )
  df = df.drop_duplicates() 
  df['negative_new_chen_score_window'] = -df['new_chen_score_window']
  df = df.drop(columns=[
    'new_chen_score_window',
    'chrom_window', 'start_window', 'end_window',
    'disease', 'enhancer_predicted_LoF_tolerance_prob', 'enhancer_predicted_LoF_tolerance_status'
  ])
  df = df.rename(columns={
    'chrom_enhancer': 'chrom', 
    'start_enhancer': 'start', 
    'end_enhancer': 'end'
  })
  df['truly constrained'] = True
  df['tag'] = 'disease_enhancers'
  return df 

read_disease_enhancers_intersect_chen_windows()
# Out:
#      chrom      start        end  negative_new_chen_score_window  \
# 0     chr1   21346107   21348107                       -3.432213
# 1     chr1   93909844   93911044                       -2.645724
# 2     chr1  155293209  155293609                       -4.190955
# 3     chr1  160032410  160033810                       -2.719339
# 4     chr1  160032410  160033810                       -0.167476
# ..     ...        ...        ...                             ...
# 116  chr20   46114761   46114961                        0.241142
# 117  chr22   28787612   28789612                        2.138137
# 118  chr22   28787612   28789612                        0.488883
# 119  chr22   28787612   28789612                        1.762075
# 120  chr22   38020193   38021993                       -3.399608
#
#      truly constrained                tag
# 0                 True  disease_enhancers
# 1                 True  disease_enhancers
# 2                 True  disease_enhancers
# 3                 True  disease_enhancers
# 4                 True  disease_enhancers
# ..                 ...                ...
# 116               True  disease_enhancers
# 117               True  disease_enhancers
# 118               True  disease_enhancers
# 119               True  disease_enhancers
# 120               True  disease_enhancers
#
# [121 rows x 6 columns]

# %%
# get low-lof-tolerance enhancers
def read_low_lof_tolerance_enhancers_intersect_chen_windows():
  # download-process-data/khurana/README.md
  df = pd.read_csv(
    f"{CONSTRAINT_TOOLS_DATA}/khurana/low-lof-tolerance-enhancers-intersect-chen-windows.bed", 
    sep = '\t',
    names = [
        'chrom_enhancer_hg38', 'start_enhancer_hg38', 'end_enhancer_hg38', 
        'enhancer_hg19', 'unknown',
        'chrom_window', 'start_window', 'end_window', 
        'new_chen_score_window'
    ]
  )
  df = df.drop_duplicates() 
  df['negative_new_chen_score_window'] = -df['new_chen_score_window']
  df = df.drop(columns=[
    'new_chen_score_window',
    'chrom_window', 'start_window', 'end_window',
    'enhancer_hg19', 'unknown'
  ])
  df = df.rename(columns={
    'chrom_enhancer_hg38': 'chrom', 
    'start_enhancer_hg38': 'start', 
    'end_enhancer_hg38': 'end'
  })
  df['truly constrained'] = True
  df['tag'] = 'low_lof_tolerance'
  return df 

read_low_lof_tolerance_enhancers_intersect_chen_windows().iloc[:10]
# Out:
#    chrom      start        end  negative_new_chen_score_window  \
# 0   chr1   61587728   61589928                       -0.884984
# 1   chr1   61587728   61589928                       -3.667483
# 2   chr1   61587728   61589928                       -1.787719
# 3   chr1   87355917   87357117                       -1.174601
# 4   chr1   87355917   87357117                       -2.971624
# 5   chr1   87355917   87357117                       -1.597840
# 9   chr1  169941659  169943659                       -0.732262
# 10  chr1  169941659  169943659                       -0.494991
# 11  chr2   66069666   66071266                       -1.628703
# 12  chr2   66069666   66071266                       -1.923346
#
#     truly constrained                tag
# 0                True  low_lof_tolerance
# 1                True  low_lof_tolerance
# 2                True  low_lof_tolerance
# 3                True  low_lof_tolerance
# 4                True  low_lof_tolerance
# 5                True  low_lof_tolerance
# 9                True  low_lof_tolerance
# 10               True  low_lof_tolerance
# 11               True  low_lof_tolerance
# 12               True  low_lof_tolerance

# %%
def aggregate_over_windows(df): 
  columns = df.columns.tolist()
  group_columns = [column for column in columns if column != 'negative_new_chen_score_window']
  groups = df.groupby(group_columns)
  aggregation_functions = {'negative_new_chen_score_window': ['min', 'count']}
  aggregated = groups.agg(aggregation_functions)  
  df = aggregated.reset_index()
  df.columns = [' '.join(col[::-1]).strip() for col in df.columns.values]
  return df

aggregate_over_windows(read_low_lof_tolerance_enhancers_intersect_chen_windows())
# Out:
#     chrom      start        end  truly constrained                tag  \
# 0    chr1   61587728   61589928               True  low_lof_tolerance
# 1    chr1   87355917   87357117               True  low_lof_tolerance
# 2    chr1  169941659  169943659               True  low_lof_tolerance
# 3   chr10  100612643  100615043               True  low_lof_tolerance
# 4   chr10  100686843  100689243               True  low_lof_tolerance
# 5   chr10  100786643  100789043               True  low_lof_tolerance
# 6   chr10  101322243  101324043               True  low_lof_tolerance
# 7   chr10  101505843  101508043               True  low_lof_tolerance
# 8   chr10  101767243  101769443               True  low_lof_tolerance
# 9   chr10  117966089  117967689               True  low_lof_tolerance
# 10  chr10  118314888  118316688               True  low_lof_tolerance
# 11  chr10  123067884  123070284               True  low_lof_tolerance
# 12  chr10  125216431  125217431               True  low_lof_tolerance
# 13  chr11    8295653    8297453               True  low_lof_tolerance
# 14  chr11   31479853   31481653               True  low_lof_tolerance
# 15  chr11   76046156   76048356               True  low_lof_tolerance
# 16  chr12  103178222  103180022               True  low_lof_tolerance
# 17  chr13   35498863   35501063               True  low_lof_tolerance
# 18  chr13   71851468   71853068               True  low_lof_tolerance
# 19  chr14   21703577   21705377               True  low_lof_tolerance
# 20  chr14   28878994   28880394               True  low_lof_tolerance
# 21  chr14   36344794   36347194               True  low_lof_tolerance
# 22  chr14   36464195   36465795               True  low_lof_tolerance
# 23  chr14   56964282   56965882               True  low_lof_tolerance
# 24  chr16   10226143   10227343               True  low_lof_tolerance
# 25  chr16   72220701   72222701               True  low_lof_tolerance
# 26  chr17   13113483   13115483               True  low_lof_tolerance
# 27  chr18   37598037   37599837               True  low_lof_tolerance
# 28   chr2   66069666   66071266               True  low_lof_tolerance
# 29   chr2  163805290  163805490               True  low_lof_tolerance
# 30   chr2  172071872  172073872               True  low_lof_tolerance
# 31   chr2  176075472  176076072               True  low_lof_tolerance
# 32  chr21   33094894   33097294               True  low_lof_tolerance
# 33   chr3    9427916    9430116               True  low_lof_tolerance
# 34   chr3  147311813  147313613               True  low_lof_tolerance
# 35   chr3  158185211  158186811               True  low_lof_tolerance
# 36   chr4  154612648  154614448               True  low_lof_tolerance
# 37   chr5  171201196  171203396               True  low_lof_tolerance
# 38   chr6   18535769   18537969               True  low_lof_tolerance
# 39   chr6  118536237  118538237               True  low_lof_tolerance
# 40   chr7   31361986   31364186               True  low_lof_tolerance
# 41   chr7   54568507   54569507               True  low_lof_tolerance
# 42   chr7   97011888   97013488               True  low_lof_tolerance
# 43   chr8   98415972   98417172               True  low_lof_tolerance
# 44   chr9    3400800    3402600               True  low_lof_tolerance
#
#     min negative_new_chen_score_window  count negative_new_chen_score_window
# 0                            -3.667483                                     3
# 1                            -2.971624                                     3
# 2                            -0.732262                                     2
# 3                            -1.667674                                     4
# 4                            -1.212765                                     4
# 5                            -2.482828                                     4
# 6                            -2.900722                                     2
# 7                            -0.350437                                     2
# 8                            -3.530818                                     3
# 9                            -0.709407                                     2
# 10                           -2.150286                                     3
# 11                           -1.760122                                     4
# 12                           -1.742165                                     2
# 13                           -1.699929                                     2
# 14                           -1.045348                                     3
# 15                           -2.827820                                     3
# 16                           -1.501731                                     2
# 17                           -1.578038                                     3
# 18                           -0.728748                                     3
# 19                           -0.902196                                     3
# 20                           -0.832646                                     3
# 21                           -0.916214                                     4
# 22                           -2.339808                                     2
# 23                           -3.866692                                     2
# 24                           -0.874568                                     2
# 25                           -0.277363                                     3
# 26                           -1.734018                                     2
# 27                           -2.086695                                     2
# 28                           -1.923346                                     3
# 29                            0.438188                                     1
# 30                           -2.464930                                     3
# 31                           -2.121999                                     2
# 32                           -0.941067                                     3
# 33                           -1.241997                                     4
# 34                            0.929155                                     3
# 35                           -0.823611                                     2
# 36                           -1.455670                                     3
# 37                           -1.534641                                     3
# 38                           -4.670357                                     3
# 39                           -0.114275                                     3
# 40                           -1.247859                                     4
# 41                           -1.270480                                     2
# 42                           -0.365397                                     2
# 43                            0.620860                                     1
# 44                           -0.622948                                     3

# %%
def get_noncoding_nonenhancer_windows():
  # this bed file has already been aggregated to the window level: 
  # experiments/germline-model/chen-et-al-2022/enhancer-characteristics-enrichment.ipynb 
  filename = f'{CONSTRAINT_TOOLS_DATA}/benchmark-genome-wide-predictions/chen-et-al-2022/enhancer-characteristics-enrichment.bed'
  df = pd.read_csv(filename, sep='\t')

  df = df[df['window overlaps merged_exon'] == False] # noncoding
  df = df[df['window overlaps enhancer'] == False] # nonenhancer

  df = df.drop_duplicates() 
  df = df[[
    'chromosome', 'start', 'end',
    'negative new chen zscore'
  ]]
  df = df.rename(columns={
    'chromosome': 'chrom', 
    'negative new chen zscore': 'min negative_new_chen_score_window'
  })
  df = df.sample(NUMBER_NEGATIVE_EXAMPLES, random_state=42) # assume most such windows are nonconstrained
  df['truly constrained'] = False
  df['tag'] = 'random_noncoding_nonenhancer'
  df['count negative_new_chen_score_window'] = 1
  return df

pd.set_option('display.max_columns', 100)

get_noncoding_nonenhancer_windows()
# Out:
#          chrom      start        end  min negative_new_chen_score_window  \
# 1267754   chr4  176610000  176611000                            1.555947
# 410987   chr12  126853000  126854000                           -1.587287
# 862482    chr2  141855000  141856000                            0.733086
# 1245664   chr4  144871000  144872000                           -1.571862
# 968282   chr20   55884000   55885000                            1.261524
# ...        ...        ...        ...                                 ...
# 930709    chr2  238681000  238682000                           -1.006325
# 416454   chr13   22471000   22472000                           -2.365208
# 293481   chr11   89095000   89096000                            4.388091
# 936347   chr20    6761000    6762000                           -2.372879
# 422652   chr13   31446000   31447000                            1.873431
#
#          truly constrained                           tag  \
# 1267754              False  random_noncoding_nonenhancer
# 410987               False  random_noncoding_nonenhancer
# 862482               False  random_noncoding_nonenhancer
# 1245664              False  random_noncoding_nonenhancer
# 968282               False  random_noncoding_nonenhancer
# ...                    ...                           ...
# 930709               False  random_noncoding_nonenhancer
# 416454               False  random_noncoding_nonenhancer
# 293481               False  random_noncoding_nonenhancer
# 936347               False  random_noncoding_nonenhancer
# 422652               False  random_noncoding_nonenhancer
#
#          count negative_new_chen_score_window
# 1267754                                     1
# 410987                                      1
# 862482                                      1
# 1245664                                     1
# 968282                                      1
# ...                                       ...
# 930709                                      1
# 416454                                      1
# 293481                                      1
# 936347                                      1
# 422652                                      1
#
# [1000 rows x 7 columns]

# %%
from shell import shell 

def check_regions_non_overlapping():
  count_self_intersections = (
    f'bedtools intersect'
    f" -a <(tail -n +2 {CONSTRAINT_TOOLS_DATA}/khurana/{LABELED_REGIONS})"
    f" -b <(tail -n +2 {CONSTRAINT_TOOLS_DATA}/khurana/{LABELED_REGIONS})"
    f' -wao'
    f' | wc -l'
  )
  number_self_intersections = shell(count_self_intersections)
  count_number_lines = f'tail -n +2 {CONSTRAINT_TOOLS_DATA}/khurana/{LABELED_REGIONS} | wc -l'
  number_lines = shell(count_number_lines)
  if number_self_intersections != number_lines:
    raise Exception(f'number of self-intersections ({number_self_intersections}) != number of lines ({number_lines})')
  else: 
    print(f'regions ({number_self_intersections}) are non-overlapping')

def create_and_save_labeled_regions(): 
  positive_examples = pd.concat([    
    aggregate_over_windows(read_disease_enhancers_intersect_chen_windows()),
    aggregate_over_windows(read_low_lof_tolerance_enhancers_intersect_chen_windows())
  ])

  negative_examples = get_noncoding_nonenhancer_windows()

  df = pd.concat([positive_examples, negative_examples])

  df = df.reset_index(drop=True) # create new index and drop old index
  df = df.reset_index(drop=False) # make new index into a column
  df = df.rename(columns={'index': 'region_id'})
  new_order = df.columns[1:].tolist() + ['region_id']
  df = df.reindex(columns=new_order)
  
  print('number of regions that are truly constrained (True) or not (False):') 
  print(df['truly constrained'].value_counts())

  df.to_csv(f"{CONSTRAINT_TOOLS_DATA}/khurana/{LABELED_REGIONS}", sep='\t', index=False)

  check_regions_non_overlapping() 

  return df 

pd.set_option('display.max_rows', 10)

create_and_save_labeled_regions()
# Out:
# number of regions that are truly constrained (True) or not (False):
# False    1000
# True      118
# Name: truly constrained, dtype: int64
#
#
# regions (1118) are non-overlapping
#       chrom      start        end  truly constrained  \
# 0      chr1   21346107   21348107               True
# 1      chr1   93909844   93911044               True
# 2      chr1  155293209  155293609               True
# 3      chr1  160032410  160033810               True
# 4      chr1  173915262  173915462               True
# ...     ...        ...        ...                ...
# 1113   chr2  238681000  238682000              False
# 1114  chr13   22471000   22472000              False
# 1115  chr11   89095000   89096000              False
# 1116  chr20    6761000    6762000              False
# 1117  chr13   31446000   31447000              False
#
#                                tag  min negative_new_chen_score_window  \
# 0                disease_enhancers                           -3.432213
# 1                disease_enhancers                           -2.645724
# 2                disease_enhancers                           -4.190955
# 3                disease_enhancers                           -2.719339
# 4                disease_enhancers                           -1.790974
# ...                            ...                                 ...
# 1113  random_noncoding_nonenhancer                           -1.006325
# 1114  random_noncoding_nonenhancer                           -2.365208
# 1115  random_noncoding_nonenhancer                            4.388091
# 1116  random_noncoding_nonenhancer                           -2.372879
# 1117  random_noncoding_nonenhancer                            1.873431
#
#       count negative_new_chen_score_window  region_id
# 0                                        1          0
# 1                                        1          1
# 2                                        1          2
# 3                                        2          3
# 4                                        1          4
# ...                                    ...        ...
# 1113                                     1       1113
# 1114                                     1       1114
# 1115                                     1       1115
# 1116                                     1       1116
# 1117                                     1       1117
#
# [1118 rows x 8 columns]

# %% [markdown]
# ## Intersect labeled regions with ALL deletions from TopMed

# %%
import numpy as np 

def collapse(ser): 
  unique_value, = set(ser)
  return unique_value

def count(ser): 
  if len(ser) == 1 and ser.iloc[0] == '.': return 0
  return len(ser) 

def custom_max(ser): 
  if len(ser) == 1 and ser.iloc[0] == '.': return '.'
  return np.max([int(value) for value in list(ser)])

def custom_list(ser): 
  if len(ser) == 1 and ser.iloc[0] == '.': return '.'
  return list(ser)

def aggregate_over_deletions(df, group_columns, aggregation_functions): 
  groups = df.groupby(group_columns)
  aggregated = groups.agg(aggregation_functions)  
  df = aggregated.reset_index()
  df.columns = [' '.join(col[::-1]).strip() for col in df.columns.values]
  return df

def read_labeled_regions_intersect_all_deletions():
  cmd = f'bash {CONSTRAINT_TOOLS}/experiments/germline-model/chen-et-al-2022/intersect-labeled-regions-{VERSION}-with-topmed-deletions.sh {VERSION}'
  print(shell(cmd))
  df = pd.read_csv(
    f"{CONSTRAINT_TOOLS_DATA}/khurana/labeled-regions-{VERSION}-intersect-topmed-deletions.bed", 
    sep = '\t',
  )  
  group_columns = [
    'chrom',
    'start',
    'end',
    'truly constrained',
    'tag',
    'min negative_new_chen_score_window',
    'count negative_new_chen_score_window',
    'region_id'
  ]
  aggregation_functions = {
    'SVLEN': [custom_max],
    'SVTYPE': [collapse, count],
    # 'SV_ID': [custom_list],
    'Het': [custom_max],
    'HomAlt': [custom_max],
    # 'region-deletion-overlap': [custom_max]
  }
  aggregation_columns = list(aggregation_functions.keys())
  new_columns = group_columns + aggregation_columns
  df = df[new_columns]
  df = aggregate_over_deletions(df, group_columns, aggregation_functions)
  df = df.rename(columns={
    'chrom': 'chrom_region',
    'start': 'start_region',
    'end': 'end_region',
  })
  df['region is deleted in topmed'] = df['collapse SVTYPE'] == 'DEL'
  print('number of regions that are deleted in TopMed (True) or not (False):')
  print(df['region is deleted in topmed'].value_counts())
  return df   
  
pd.set_option('display.max_rows', 1000)

REGIONS = read_labeled_regions_intersect_all_deletions()
REGIONS
# Out:
# Wrote labeled regions with intersecting topmed deletions to: /scratch/ucgd/lustre-work/quinlan/data-shared/constraint-tools/khurana/labeled-regions-4-intersect-topmed-deletions.bed
#
# number of regions that are deleted in TopMed (True) or not (False):
# True     865
# False    253
# Name: region is deleted in topmed, dtype: int64
#      chrom_region  start_region  end_region  truly constrained  \
# 0            chr1      17253000    17254000              False
# 1            chr1      19832000    19833000              False
# 2            chr1      20541000    20542000              False
# 3            chr1      21346107    21348107               True
# 4            chr1      31722000    31723000              False
# ...           ...           ...         ...                ...
# 1113         chr9     116175000   116176000              False
# 1114         chr9     118516000   118517000              False
# 1115         chr9     118769000   118770000              False
# 1116         chr9     121677000   121678000              False
# 1117         chr9     122212000   122213000              False
#
#                                tag  min negative_new_chen_score_window  \
# 0     random_noncoding_nonenhancer                           -1.995430
# 1     random_noncoding_nonenhancer                           -0.454322
# 2     random_noncoding_nonenhancer                           -1.825657
# 3                disease_enhancers                           -3.432213
# 4     random_noncoding_nonenhancer                           -1.271066
# ...                            ...                                 ...
# 1113  random_noncoding_nonenhancer                            0.367846
# 1114  random_noncoding_nonenhancer                            1.470814
# 1115  random_noncoding_nonenhancer                            0.594347
# 1116  random_noncoding_nonenhancer                           -0.829970
# 1117  random_noncoding_nonenhancer                           -2.624012
#
#       count negative_new_chen_score_window  region_id custom_max SVLEN  \
# 0                                        1        180            22338
# 1                                        1        723           660857
# 2                                        1        819             6592
# 3                                        1          0          7098532
# 4                                        1        783           501200
# ...                                    ...        ...              ...
# 1113                                     1        270            12700
# 1114                                     1        253           250633
# 1115                                     1        725                .
# 1116                                     1        727             5559
# 1117                                     1        941                .
#
#      collapse SVTYPE  count SVTYPE custom_max Het custom_max HomAlt  \
# 0                DEL             1              1                 0
# 1                DEL             1              1                 0
# 2                DEL             1              6                 0
# 3                DEL             1          11209                 0
# 4                DEL             2              2                 0
# ...              ...           ...            ...               ...
# 1113             DEL             1              1                 0
# 1114             DEL             1              1                 0
# 1115               .             0              .                 .
# 1116             DEL             1              2                 0
# 1117               .             0              .                 .
#
#       region is deleted in topmed
# 0                            True
# 1                            True
# 2                            True
# 3                            True
# 4                            True
# ...                           ...
# 1113                         True
# 1114                         True
# 1115                        False
# 1116                         True
# 1117                        False
#
# [1118 rows x 14 columns]

# %% [markdown]
# ## Using Chen zscore to predict whether a region is critical or not, and improving that prediction using TopMed deletions

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# Set the font size
mpl.rcParams['font.size'] = 20

def plot_score_distributions(df, score, xlabel, bins, xlim=None):
  ax = sns.histplot(data=df, x=score, kde=True, bins=bins, hue='truly constrained', stat='count') # stat='density'
  ax.set_xlabel(xlabel)
  ax.set_ylabel('Number of regions')
  if xlim is not None: ax.set_xlim(xlim)
  legend = ax.get_legend()
  legend.set_title('region truly constrained?')
  fig = plt.gcf()
  fig.set_size_inches(10, 5)
  plt.show()

  # Compute the area under the curve for each histogram
  for container in ax.containers:
    print(container.get_label())
    area = 0
    for bar in container.patches:
      area += bar.get_width() * bar.get_height()
    print(f"Area under the curve: {area:.2f}")

plot_score_distributions(REGIONS, score='min negative_new_chen_score_window', xlabel='Chen score of region', bins=40, xlim=(-6, 6))
plot_score_distributions(REGIONS, score='count SVTYPE', xlabel='Number of deletions overlapping region', bins=250, xlim=(0, 20))
# Out:
# _container0
# Area under the curve: 47.46
# _container1
# Area under the curve: 402.24
# _container0
# Area under the curve: 120.36
# _container1
# Area under the curve: 1020.00

# %%
def predict_constraint_without_deletions(df, zscore_threshold): 
  score = 'min negative_new_chen_score_window'
  df = df[[score, 'truly constrained']].copy()
  df['predicted to be constrained'] = df[score] < zscore_threshold
  return df

predict_constraint_without_deletions(REGIONS, zscore_threshold=-2)
# Out:
#       min negative_new_chen_score_window  truly constrained  \
# 0                              -1.995430              False
# 1                              -0.454322              False
# 2                              -1.825657              False
# 3                              -3.432213               True
# 4                              -1.271066              False
# ...                                  ...                ...
# 1113                            0.367846              False
# 1114                            1.470814              False
# 1115                            0.594347              False
# 1116                           -0.829970              False
# 1117                           -2.624012              False
#
#       predicted to be constrained
# 0                           False
# 1                           False
# 2                           False
# 3                            True
# 4                           False
# ...                           ...
# 1113                        False
# 1114                        False
# 1115                        False
# 1116                        False
# 1117                         True
#
# [1118 rows x 3 columns]

# %%
def predict_constraint_using_deletions(df, zscore_threshold): 
  score = 'min negative_new_chen_score_window'
  df = df[[
    score, 
    'truly constrained', 
    'region is deleted in topmed'
  ]].copy()
  df['predicted to be constrained'] = (
    (df[score] < zscore_threshold) & 
    (df['region is deleted in topmed'] == False)
  )
  return df

pd.set_option('display.max_rows', 10)

predict_constraint_using_deletions(REGIONS, zscore_threshold=-2)
# Out:
#       min negative_new_chen_score_window  truly constrained  \
# 0                              -1.995430              False
# 1                              -0.454322              False
# 2                              -1.825657              False
# 3                              -3.432213               True
# 4                              -1.271066              False
# ...                                  ...                ...
# 1113                            0.367846              False
# 1114                            1.470814              False
# 1115                            0.594347              False
# 1116                           -0.829970              False
# 1117                           -2.624012              False
#
#       region is deleted in topmed  predicted to be constrained
# 0                            True                        False
# 1                            True                        False
# 2                            True                        False
# 3                            True                        False
# 4                            True                        False
# ...                           ...                          ...
# 1113                         True                        False
# 1114                         True                        False
# 1115                        False                        False
# 1116                         True                        False
# 1117                        False                         True
#
# [1118 rows x 4 columns]

# %%
def compute_precision_recall(df, zscore_threshold, predict_constraint, log=False): 
  df = predict_constraint(df, zscore_threshold)
  
  contingency_table = pd.crosstab(
    df['predicted to be constrained'], 
    df['truly constrained']
  )

  if log:   
    print(zscore_threshold)
    print(contingency_table)

  tp = contingency_table.loc[True, True]
  fp = contingency_table.loc[True, False]
  fn = contingency_table.loc[False, True]
  precision = tp / (tp + fp)
  recall = tp / (tp + fn)

  return precision, recall
  
compute_precision_recall(REGIONS, zscore_threshold=-3, predict_constraint=predict_constraint_without_deletions, log=True)
# Out:
# -3
# truly constrained            False  True
# predicted to be constrained
# False                          978   104
# True                            22    14
# (0.3888888888888889, 0.11864406779661017)

# %%
compute_precision_recall(REGIONS, zscore_threshold=-3, predict_constraint=predict_constraint_using_deletions, log=True)
# Out:
# -3
# truly constrained            False  True
# predicted to be constrained
# False                          994   110
# True                             6     8
# (0.5714285714285714, 0.06779661016949153)

# %%
def plot_precision_recall(df, predict_constraint, label): 
  zscore_thresholds = np.arange(-6, 5.5, 0.1) 
  precision_recall = [
    compute_precision_recall(df, zscore_threshold, predict_constraint, log=False)
    for zscore_threshold in zscore_thresholds
  ]
  precisions, recalls = zip(*precision_recall)
  plt.plot(recalls, precisions, label=label)

def plot_precision_recall_wrapper(df): 
  plot_precision_recall(df, predict_constraint_without_deletions, label='without using topmed deletions')
  plot_precision_recall(df, predict_constraint_using_deletions, label='using topmed deletions')
  plt.xlabel('Recall')
  plt.ylabel('Precision')
  plt.legend()
  fig = plt.gcf()
  fig.set_size_inches(10, 5)

  number_unconstrained_regions = df['truly constrained'].value_counts().loc[False]
  number_constrained_regions = df['truly constrained'].value_counts().loc[True]
  plt.title(
    'Predicting constraint on\n'
    f'{number_unconstrained_regions} unconstrained regions\n'
    f'and {number_constrained_regions} constrained regions'
  )
  
plot_precision_recall_wrapper(REGIONS)
