# %% [markdown]
# ## Fetch windows and their zscores and annotations

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width: 100% !important; }</style>"))
# Out:
# <style>.container { width: 100% !important; }</style>

# %%
CONSTRAINT_TOOLS_DATA = '/scratch/ucgd/lustre-work/quinlan/data-shared/constraint-tools'

# %%
import pandas as pd 

pd.set_option('display.max_columns', 50)

def get_windows_scores_annotations():
    # the following bed file was produced by experiments/germline-model/chen-et-al-2022/Fig_2a.Nonly.noisy.ipynb
    filename = f'{CONSTRAINT_TOOLS_DATA}/benchmark-genome-wide-predictions/chen-et-al-2022/mchale.kmerSizes.trainSets.noisy.enhancer-exon.bed'
    df = pd.read_csv(filename, sep='\t')
    return df

windows_scores_annotations = get_windows_scores_annotations()
windows_scores_annotations
# Out:
#         chromosome      start        end  N_observed  N_bar_7_noncoding  \
# 0             chr1    1432000    1433000         260          -0.372778
# 1             chr1    1435000    1436000         275          -6.280673
# 2             chr1    1449000    1450000         225           0.139977
# 3             chr1    1450000    1451000         313           2.524948
# 4             chr1    1451000    1452000         293           2.951595
# ...            ...        ...        ...         ...                ...
# 1786072       chr9  137269000  137270000         210          -3.060479
# 1786073       chr9  137275000  137276000         296           1.990841
# 1786074       chr9  137282000  137283000         211          -1.612483
# 1786075       chr9  137290000  137291000         224          -0.215971
# 1786076       chr9  137294000  137295000         182          -5.354983
#
#          N_mean_null_7_noncoding  N_variance_null_7_noncoding  \
# ...

# %%
windows_scores_annotations_coding = windows_scores_annotations[windows_scores_annotations['window overlaps merged_exon'] == True]
windows_scores_annotations_coding
# Out:
#         chromosome      start        end  N_observed  N_bar_7_noncoding  \
# 1             chr1    1435000    1436000         275          -6.280673
# 2             chr1    1449000    1450000         225           0.139977
# 3             chr1    1450000    1451000         313           2.524948
# 6             chr1    1454000    1455000         350           4.047235
# 8             chr1    1459000    1460000         263          -0.472788
# ...            ...        ...        ...         ...                ...
# 1786066       chr9  137212000  137213000         230          -1.772751
# 1786067       chr9  137234000  137235000         335           3.003031
# 1786068       chr9  137235000  137236000         289           1.541670
# 1786074       chr9  137282000  137283000         211          -1.612483
# 1786076       chr9  137294000  137295000         182          -5.354983
#
#          N_mean_null_7_noncoding  N_variance_null_7_noncoding  \
# ...

# %%
windows_scores_annotations_noncoding = windows_scores_annotations[windows_scores_annotations['window overlaps merged_exon'] == False]
windows_scores_annotations_noncoding
# Out:
#         chromosome      start        end  N_observed  N_bar_7_noncoding  \
# 0             chr1    1432000    1433000         260          -0.372778
# 4             chr1    1451000    1452000         293           2.951595
# 5             chr1    1453000    1454000         260           1.389878
# 7             chr1    1458000    1459000         274           2.218475
# 11            chr1    1463000    1464000         192          -1.944466
# ...            ...        ...        ...         ...                ...
# 1786070       chr9  137262000  137263000         303           4.459653
# 1786071       chr9  137268000  137269000         215          -1.116078
# 1786072       chr9  137269000  137270000         210          -3.060479
# 1786073       chr9  137275000  137276000         296           1.990841
# 1786075       chr9  137290000  137291000         224          -0.215971
#
#          N_mean_null_7_noncoding  N_variance_null_7_noncoding  \
# ...

# %% [markdown]
# ## Windows whose zscores differ most, are also windows in the tail of the zscore distribution, and are windows for which N_mean_null is most different

# %%
import seaborn as sns 
sns.set(font_scale = 1)

import matplotlib.pyplot as plt

# %%
def all_pairplots1(df, kmer_size):
    df.plot.scatter(x=f'N_bar_{kmer_size}_noncoding', y=f'N_mean_null_{kmer_size}_noncoding')
    df.plot.scatter(x=f'N_bar_{kmer_size}_noncoding', y=f'N_variance_null_{kmer_size}_noncoding')
    
all_pairplots1(windows_scores_annotations_coding, kmer_size=3)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
def pairplot(df, score_type, xlim, ylim, downsample=False):
    if downsample: df = df.sample(n=1000, replace=True)
    columns = [f'N_{score_type}_{kmer_size}_noncoding' for kmer_size in [1, 3, 5, 7]]    
    df = df[columns]
    g = sns.pairplot(df, corner=True, kind='hist')
    fig = plt.gcf()
    fig.set_size_inches(20, 20)
    for i in range(4): 
        for j in range(i+1):            
            g.axes[i,j].set_xlim(xlim)
    for i in range(1,4): 
        for j in range(i):            
            g.axes[i,j].set_ylim(ylim)
            g.axes[i,j].plot(xlim, xlim, 'r-')

# %%
def all_pairplots2(df):
    pairplot(df, score_type='bar', xlim=[-15, 15], ylim=[-15, 15])
    pairplot(df, score_type='mean_null', xlim=[150, 500], ylim=[150, 500], downsample=False)
    pairplot(df, score_type='variance_null', xlim=[150, 250], ylim=[150, 300], downsample=False)

# %%
all_pairplots2(windows_scores_annotations_coding)

# %% [markdown]
# ## [TODO] Sequence of low-zscore windows

# %%
def get_low_zscore_windows(df): 
    df = df[df['N_bar_3_noncoding'] < -10]
    plt.hist((df['N_mean_null_7_noncoding'] - df['N_mean_null_3_noncoding']))
    plt.xlabel('N_mean_null_7_noncoding - N_mean_null_3_noncoding')
    plt.show()
    return df

get_low_zscore_windows(windows_scores_annotations_coding)
# Out:
#         chromosome      start        end  N_observed  N_bar_7_noncoding  \
# 84            chr1    1599000    1600000         274          -7.781961
# 1239          chr1    4654000    4655000         291          -8.474438
# 2389          chr1    6419000    6420000         252          -9.218712
# 4628          chr1    9997000    9998000         240         -10.210983
# 5016          chr1   10639000   10640000         257          -9.405473
# ...            ...        ...        ...         ...                ...
# 1782938       chr9  130681000  130682000         229         -11.586328
# 1785477       chr9  135479000  135480000         307          -8.193690
# 1785884       chr9  136545000  136546000         265          -9.071559
# 1786015       chr9  137028000  137029000         251         -10.545575
# 1786054       chr9  137139000  137140000         224         -10.334195
#
#          N_mean_null_7_noncoding  N_variance_null_7_noncoding  \
# ...

# %%
# /uufs/chpc.utah.edu/common/HIPAA/u6018199/.conda/envs/constraint-tools/lib/python3.9/site-packages/pyranges/get_fasta.py

import pyranges as pr

def f(df):
    columns = ['chromosome', 'start', 'end']
    df = df[columns]
    df = df.rename(columns={
        column: column.title()
        for column in columns
    })
    gr = pr.PyRanges(df)
    genome="/scratch/ucgd/lustre-work/quinlan/data-shared/constraint-tools/reference/grch38/hg38.analysisSet.fa.gz"
    seq= pr.get_fasta(gr, genome)
    gr.seq = seq
    return gr

pd.set_option('max_colwidth', 1200)

f(get_low_zscore_windows(windows_scores_annotations_coding)[:5])
# Out:
# +--------------+-----------+-----------+-------+
# | Chromosome   |     Start |       End | +1    |
# | (category)   |   (int32) |   (int32) | ...   |
# |--------------+-----------+-----------+-------|
# | chr1         |   1599000 |   1600000 | ...   |
# | chr1         |   4654000 |   4655000 | ...   |
# | chr1         |   6419000 |   6420000 | ...   |
# | chr1         |   9997000 |   9998000 | ...   |
# | chr1         |  10639000 |  10640000 | ...   |
# +--------------+-----------+-----------+-------+
# Unstranded PyRanges object has 5 rows and 4 columns from 1 chromosomes.
# For printing, the PyRanges was sorted on Chromosome.
# 1 hidden columns: seq
