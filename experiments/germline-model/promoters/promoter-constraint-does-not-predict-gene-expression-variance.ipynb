# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# John Chamberlin's Hypothesis: "High CpG density may be useful for permitting either strong repression or activation of genes which are highly tissue- or context-specific"
# Test the hypothesis: "compare the variance in gene expression across tissues to the CpG density of their promoters"

# Data: 
#   gene expression level and variance: 
#     https://www.embopress.org/doi/full/10.15252/msb.20209539
#   CpG density: 
#     https://www.sciencedirect.com/science/article/pii/S0002929720302445?via%3Dihub
#     https://ars.els-cdn.com/content/image/1-s2.0-S0002929720302445-mmc1.pdf

# %%
import pandas as pd 

gene_expression_variation = pd.read_csv('/scratch/ucgd/lustre-work/quinlan/data-shared/constraint-tools/promoters/grch38/Sigalova2020/Dataset_EV10_all_variations.csv')
gene_expression_variation
# Out:
#       gene_name          gene_id  Adipose...Subcutaneous_mean  \
# 0          DPM1  ENSG00000000419                     7.346319
# 1           XDH  ENSG00000158125                          NaN
# 2          COA5  ENSG00000183513                     7.266417
# 3       ARHGDIB  ENSG00000111348                          NaN
# 4        NMNAT2  ENSG00000157064                     6.828882
# ...         ...              ...                          ...
# 11307     AMER3  ENSG00000178171                          NaN
# 11308      BROX  ENSG00000162819                     7.609070
# 11309     SPAG6  ENSG00000077327                          NaN
# 11310   FAM120A  ENSG00000048828                          NaN
# 11311     FSCN1  ENSG00000075618                     8.115095
#
#        Adipose...Subcutaneous_median  Adipose...Subcutaneous_cv  \
# 0                           7.318724                  -1.727679
# 1                                NaN                        NaN
# 2                           7.257528                  -1.912434
# 3                                NaN                        NaN
# 4                           6.656019                  -0.465854
# ...                              ...                        ...
# 11307                            NaN                        NaN
# 11308                       7.600106                  -1.696329
# 11309                            NaN                        NaN
# 11310                            NaN                        NaN
# 11311                       7.953384                  -0.569193
#
#        Adipose...Subcutaneous_residual_cv  Adipose...Visceral..Omentum._mean  \
# 0                               -0.477543                           7.363085
# 1                                     NaN                                NaN
# 2                               -0.666104                           7.083291
# 3                                     NaN                                NaN
# 4                                0.686289                           7.075040
# ...                                   ...                                ...
# 11307                                 NaN                                NaN
# 11308                           -0.401392                           7.440338
# 11309                                 NaN                                NaN
# 11310                                 NaN                                NaN
# 11311                            0.770261                           8.130938
#
#        Adipose...Visceral..Omentum._median  Adipose...Visceral..Omentum._cv  \
# 0                                 7.324162                        -1.616095
# 1                                      NaN                              NaN
# 2                                 7.075745                        -1.540021
# 3                                      NaN                              NaN
# 4                                 6.831370                        -0.266864
# ...                                    ...                              ...
# 11307                                  NaN                              NaN
# 11308                             7.430043                        -1.629705
# 11309                                  NaN                              NaN
# 11310                                  NaN                              NaN
# 11311                             8.014948                        -0.631326
#
#        Adipose...Visceral..Omentum._residual_cv  ...  Thyroid_resid_cv  \
# 0                                     -0.489283  ...         -0.608713
# 1                                           NaN  ...               NaN
# 2                                     -0.449251  ...         -0.421263
# 3                                           NaN  ...          0.408878
# 4                                      0.791546  ...          1.136185
# ...                                         ...  ...               ...
# 11307                                       NaN  ...               NaN
# 11308                                 -0.481036  ...         -0.306763
# 11309                                       NaN  ...               NaN
# 11310                                       NaN  ...               NaN
# 11311                                  0.561369  ...          0.404553
#
#        Uterus_resid_cv  Vagina_resid_cv  Whole.Blood_resid_cv  DE_Prior_Rank  \
# 0            -0.612328        -0.570814              0.069324       0.252086
# 1                  NaN              NaN                   NaN       0.919049
# 2            -0.539233        -0.695383             -0.079946       0.395968
# 3             0.326218         0.353276                   NaN       0.910651
# 4             0.631039         0.432596                   NaN       0.885693
# ...                ...              ...                   ...            ...
# 11307              NaN              NaN                   NaN       0.121688
# 11308        -0.310984         0.020878              0.082738       0.600694
# 11309              NaN              NaN                   NaN       0.627451
# 11310              NaN              NaN             -0.430287       0.649489
# 11311         0.597733         0.967543              0.575543       0.882902
#
#        GWAS_UPSTREAM_GENE_ID  GWAS_DOWNSTREAM_GENE_ID  CEGv2_subset  \
# 0                         NO                       NO            NO
# 1                         NO                       NO            NO
# 2                         NO                       NO           YES
# 3                         NO                       NO            NO
# 4                        YES                       NO            NO
# ...                      ...                      ...           ...
# 11307                     NO                       NO            NO
# 11308                     NO                       NO            NO
# 11309                     NO                       NO            NO
# 11310                    YES                       NO            NO
# 11311                     NO                      YES            NO
#
#        drug_targets_nelson  FDA_approved_drug_targets
# 0                       NO                         NO
# 1                       NO                        YES
# 2                       NO                         NO
# 3                       NO                         NO
# 4                      YES                         NO
# ...                    ...                        ...
# 11307                   NO                         NO
# 11308                   NO                         NO
# 11309                   NO                         NO
# 11310                   NO                         NO
# 11311                   NO                         NO
#
# [11312 rows x 227 columns]

# %%
for column_heading in gene_expression_variation.columns: 
    print(column_heading)
# Out:
# gene_name
# gene_id
# Adipose...Subcutaneous_mean
# Adipose...Subcutaneous_median
# Adipose...Subcutaneous_cv
# Adipose...Subcutaneous_residual_cv
# Adipose...Visceral..Omentum._mean
# Adipose...Visceral..Omentum._median
# Adipose...Visceral..Omentum._cv
# Adipose...Visceral..Omentum._residual_cv
# Adrenal.Gland_mean
# Adrenal.Gland_median
# Adrenal.Gland_cv
# Adrenal.Gland_residual_cv
# Artery...Aorta_mean
# Artery...Aorta_median
# Artery...Aorta_cv
# Artery...Aorta_residual_cv
# Artery...Coronary_mean
# Artery...Coronary_median
# Artery...Coronary_cv
# Artery...Coronary_residual_cv
# Artery...Tibial_mean
# Artery...Tibial_median
# Artery...Tibial_cv
# Artery...Tibial_residual_cv
# Brain...Anterior.cingulate.cortex..BA24._mean
# Brain...Anterior.cingulate.cortex..BA24._median
# Brain...Anterior.cingulate.cortex..BA24._cv
# Brain...Anterior.cingulate.cortex..BA24._residual_cv
# Brain...Caudate..basal.ganglia._mean
# Brain...Caudate..basal.ganglia._median
# Brain...Caudate..basal.ganglia._cv
# Brain...Caudate..basal.ganglia._residual_cv
# Brain...Cerebellar.Hemisphere_mean
# Brain...Cerebellar.Hemisphere_median
# Brain...Cerebellar.Hemisphere_cv
# Brain...Cerebellar.Hemisphere_residual_cv
# Brain...Cerebellum_mean
# Brain...Cerebellum_median
# Brain...Cerebellum_cv
# Brain...Cerebellum_residual_cv
# Brain...Cortex_mean
# Brain...Cortex_median
# Brain...Cortex_cv
# Brain...Cortex_residual_cv
# Brain...Frontal.Cortex..BA9._mean
# Brain...Frontal.Cortex..BA9._median
# Brain...Frontal.Cortex..BA9._cv
# Brain...Frontal.Cortex..BA9._residual_cv
# Brain...Hippocampus_mean
# Brain...Hippocampus_median
# Brain...Hippocampus_cv
# Brain...Hippocampus_residual_cv
# Brain...Hypothalamus_mean
# Brain...Hypothalamus_median
# Brain...Hypothalamus_cv
# Brain...Hypothalamus_residual_cv
# Brain...Nucleus.accumbens..basal.ganglia._mean
# Brain...Nucleus.accumbens..basal.ganglia._median
# Brain...Nucleus.accumbens..basal.ganglia._cv
# Brain...Nucleus.accumbens..basal.ganglia._residual_cv
# Brain...Putamen..basal.ganglia._mean
# Brain...Putamen..basal.ganglia._median
# Brain...Putamen..basal.ganglia._cv
# Brain...Putamen..basal.ganglia._residual_cv
# Breast...Mammary.Tissue_mean
# Breast...Mammary.Tissue_median
# Breast...Mammary.Tissue_cv
# Breast...Mammary.Tissue_residual_cv
# Cells...EBV.transformed.lymphocytes_mean
# Cells...EBV.transformed.lymphocytes_median
# Cells...EBV.transformed.lymphocytes_cv
# Cells...EBV.transformed.lymphocytes_residual_cv
# Colon...Sigmoid_mean
# Colon...Sigmoid_median
# Colon...Sigmoid_cv
# Colon...Sigmoid_residual_cv
# Colon...Transverse_mean
# Colon...Transverse_median
# Colon...Transverse_cv
# Colon...Transverse_residual_cv
# Esophagus...Gastroesophageal.Junction_mean
# Esophagus...Gastroesophageal.Junction_median
# Esophagus...Gastroesophageal.Junction_cv
# Esophagus...Gastroesophageal.Junction_residual_cv
# Esophagus...Mucosa_mean
# Esophagus...Mucosa_median
# Esophagus...Mucosa_cv
# Esophagus...Mucosa_residual_cv
# Esophagus...Muscularis_mean
# Esophagus...Muscularis_median
# Esophagus...Muscularis_cv
# Esophagus...Muscularis_residual_cv
# Heart...Atrial.Appendage_mean
# Heart...Atrial.Appendage_median
# Heart...Atrial.Appendage_cv
# Heart...Atrial.Appendage_residual_cv
# Heart...Left.Ventricle_mean
# Heart...Left.Ventricle_median
# Heart...Left.Ventricle_cv
# Heart...Left.Ventricle_residual_cv
# Liver_mean
# Liver_median
# Liver_cv
# Liver_residual_cv
# Lung_mean
# Lung_median
# Lung_cv
# Lung_residual_cv
# Muscle...Skeletal_mean
# Muscle...Skeletal_median
# Muscle...Skeletal_cv
# Muscle...Skeletal_residual_cv
# Nerve...Tibial_mean
# Nerve...Tibial_median
# Nerve...Tibial_cv
# Nerve...Tibial_residual_cv
# Ovary_mean
# Ovary_median
# Ovary_cv
# Ovary_residual_cv
# Pancreas_mean
# Pancreas_median
# Pancreas_cv
# Pancreas_residual_cv
# Pituitary_mean
# Pituitary_median
# Pituitary_cv
# Pituitary_residual_cv
# Prostate_mean
# Prostate_median
# Prostate_cv
# Prostate_residual_cv
# Skin...Not.Sun.Exposed..Suprapubic._mean
# Skin...Not.Sun.Exposed..Suprapubic._median
# Skin...Not.Sun.Exposed..Suprapubic._cv
# Skin...Not.Sun.Exposed..Suprapubic._residual_cv
# Skin...Sun.Exposed..Lower.leg._mean
# Skin...Sun.Exposed..Lower.leg._median
# Skin...Sun.Exposed..Lower.leg._cv
# Skin...Sun.Exposed..Lower.leg._residual_cv
# Small.Intestine...Terminal.Ileum_mean
# Small.Intestine...Terminal.Ileum_median
# Small.Intestine...Terminal.Ileum_cv
# Small.Intestine...Terminal.Ileum_residual_cv
# Spleen_mean
# Spleen_median
# Spleen_cv
# Spleen_residual_cv
# Stomach_mean
# Stomach_median
# Stomach_cv
# Stomach_residual_cv
# Testis_mean
# Testis_median
# Testis_cv
# Testis_residual_cv
# Thyroid_mean
# Thyroid_median
# Thyroid_cv
# Thyroid_residual_cv
# Uterus_mean
# Uterus_median
# Uterus_cv
# Uterus_residual_cv
# Vagina_mean
# Vagina_median
# Vagina_cv
# Vagina_residual_cv
# Whole.Blood_mean
# Whole.Blood_median
# Whole.Blood_cv
# Whole.Blood_residual_cv
# mean_median
# mean_cv
# mean_variation
# mean_variation_global
# Adipose...Subcutaneous_resid_cv
# Adipose...Visceral..Omentum._resid_cv
# Adrenal.Gland_resid_cv
# Artery...Aorta_resid_cv
# Artery...Coronary_resid_cv
# Artery...Tibial_resid_cv
# Brain...Anterior.cingulate.cortex..BA24._resid_cv
# Brain...Caudate..basal.ganglia._resid_cv
# Brain...Cerebellar.Hemisphere_resid_cv
# Brain...Cerebellum_resid_cv
# Brain...Cortex_resid_cv
# Brain...Frontal.Cortex..BA9._resid_cv
# Brain...Hippocampus_resid_cv
# Brain...Hypothalamus_resid_cv
# Brain...Nucleus.accumbens..basal.ganglia._resid_cv
# Brain...Putamen..basal.ganglia._resid_cv
# Breast...Mammary.Tissue_resid_cv
# Cells...EBV.transformed.lymphocytes_resid_cv
# Colon...Sigmoid_resid_cv
# Colon...Transverse_resid_cv
# Esophagus...Gastroesophageal.Junction_resid_cv
# Esophagus...Mucosa_resid_cv
# Esophagus...Muscularis_resid_cv
# Heart...Atrial.Appendage_resid_cv
# Heart...Left.Ventricle_resid_cv
# Liver_resid_cv
# Lung_resid_cv
# Muscle...Skeletal_resid_cv
# Nerve...Tibial_resid_cv
# Ovary_resid_cv
# Pancreas_resid_cv
# Pituitary_resid_cv
# Prostate_resid_cv
# Skin...Not.Sun.Exposed..Suprapubic._resid_cv
# Skin...Sun.Exposed..Lower.leg._resid_cv
# Small.Intestine...Terminal.Ileum_resid_cv
# Spleen_resid_cv
# Stomach_resid_cv
# Testis_resid_cv
# Thyroid_resid_cv
# Uterus_resid_cv
# Vagina_resid_cv
# Whole.Blood_resid_cv
# DE_Prior_Rank
# GWAS_UPSTREAM_GENE_ID
# GWAS_DOWNSTREAM_GENE_ID
# CEGv2_subset
# drug_targets_nelson
# FDA_approved_drug_targets

# %%
# see the column "mean_variation_global" is referenced in Measuring expression level and variation in human tissues" at https://www.embopress.org/doi/full/10.15252/msb.20209539
gene_expression_variation = gene_expression_variation[['gene_name', 'gene_id', 'mean_variation_global']]
gene_expression_variation
# Out:
#       gene_name          gene_id  mean_variation_global
# 0          DPM1  ENSG00000000419              -0.651344
# 1           XDH  ENSG00000158125               0.725784
# 2          COA5  ENSG00000183513              -0.696164
# 3       ARHGDIB  ENSG00000111348               0.347273
# 4        NMNAT2  ENSG00000157064               0.430554
# ...         ...              ...                    ...
# 11307     AMER3  ENSG00000178171              -0.079337
# 11308      BROX  ENSG00000162819              -0.445117
# 11309     SPAG6  ENSG00000077327               0.659075
# 11310   FAM120A  ENSG00000048828              -0.454470
# 11311     FSCN1  ENSG00000075618               0.541503
#
# [11312 rows x 3 columns]

# %%
def get_promoters_and_loeuf(number_neutral_bases):
    number_neutral_bases_lower, number_neutral_bases_upper = tuple(map(int, number_neutral_bases.split(',')))
    CONSTRAINT_TOOLS_DATA = '/scratch/ucgd/lustre-work/quinlan/data-shared/constraint-tools'
    promoters_filename = (
        f'{CONSTRAINT_TOOLS_DATA}/promoters/grch38/'
        f'promoters-with-zscores.{number_neutral_bases_lower}-{number_neutral_bases_upper}.bed'
    )
    df = pd.read_csv(promoters_filename, sep='\t')
    
    # filter NaN
    is_NaN = df.isnull()
    row_has_NaN = is_NaN.any(axis=1)
    df = df[row_has_NaN == False]
    
    return df

frames = [get_promoters_and_loeuf(number_neutral_bases) for number_neutral_bases in [
    "150,200",
    "200,250",
    "250,300", 
    "300,400",
    "400,500",
    "500,600",
    "600,750",
    "750,1000",
]]
promoters_and_loeuf = pd.concat(frames, ignore_index=True)

promoters_and_loeuf = promoters_and_loeuf[['gene_name', 'gene_id', 'cpg_density_region_grch38', 'loeuf', 'promoter_phastcons', 'N_bar_mean_neutral', 'K_bar_mean_neutral']]
promoters_and_loeuf
# Out:
#      gene_name          gene_id  cpg_density_region_grch38  loeuf  \
# 0       HNRNPU  ENSG00000153187                   0.965798  0.118
# 1        H3F3A  ENSG00000163041                   0.902507  1.157
# 2        BCAR3  ENSG00000137936                   0.856014  0.396
# 3       CACYBP  ENSG00000116161                   0.766252  0.378
# 4       ARID4B  ENSG00000054267                   0.746902  0.189
# ...        ...              ...                        ...    ...
# 9253  C22orf31  ENSG00000100249                   0.246248  1.467
# 9254    CRYBB2  ENSG00000244752                   0.240393  0.614
# 9255    SLC5A1  ENSG00000100170                   0.177320  0.746
# 9256   SEC14L3  ENSG00000100012                   0.146733  1.639
# 9257      XKR3  ENSG00000172967                   0.121645  0.945
#
#       promoter_phastcons  N_bar_mean_neutral  K_bar_mean_neutral
# 0               0.343500            1.900500            0.120430
# 1               0.364550           -1.330061            0.025603
# 2               0.121925           -2.064132            0.999113
# 3               0.040050           -0.004744            0.914405
# 4               0.276475           -1.400205           -1.059925
# ...                  ...                 ...                 ...
# 9253            0.255675            0.766787            0.192697
# 9254            0.095175            0.132702           -0.521678
# 9255            0.091225           -0.978971           -0.510705
# 9256            0.099950           -0.232547            0.313165
# 9257            0.281825            0.661104            0.250488
#
# [9258 rows x 7 columns]

# %%
promoters_loeuf_expressionVariation = pd.merge(
    promoters_and_loeuf,
    gene_expression_variation, 
    on='gene_id', 
    how='inner'
)
promoters_loeuf_expressionVariation
# Out:
#       gene_name_x          gene_id  cpg_density_region_grch38  loeuf  \
# 0           BCAR3  ENSG00000137936                   0.856014  0.396
# 1          ARID4B  ENSG00000054267                   0.746902  0.189
# 2           RSBN1  ENSG00000081019                   0.724217  0.435
# 3           SUSD4  ENSG00000143502                   0.705071  0.734
# 4           MAGI3  ENSG00000081026                   0.698284  0.387
# ...           ...              ...                        ...    ...
# 5978  AC002472.13  ENSG00000187905                   0.350211  1.650
# 5979       LGALS1  ENSG00000100097                   0.346850  1.667
# 5980        NFAM1  ENSG00000235568                   0.296590  1.215
# 5981       VPREB3  ENSG00000128218                   0.283518  1.885
# 5982       SLC5A1  ENSG00000100170                   0.177320  0.746
#
#       promoter_phastcons  N_bar_mean_neutral  K_bar_mean_neutral gene_name_y  \
# 0               0.121925           -2.064132            0.999113       BCAR3
# 1               0.276475           -1.400205           -1.059925      ARID4B
# 2               0.290900           -0.816445           -0.293793       RSBN1
# 3               0.222000           -2.608241            0.316959       SUSD4
# 4               0.315775           -2.727076            0.987644       MAGI3
# ...                  ...                 ...                 ...         ...
# 5978            0.112625           -1.195286            0.785858     LRRC74B
# 5979            0.116800           -0.314059            0.127069      LGALS1
# 5980            0.064800           -0.276616           -0.311553       NFAM1
# 5981            0.076225            0.356627           -0.324641      VPREB3
# 5982            0.091225           -0.978971           -0.510705      SLC5A1
#
#       mean_variation_global
# 0                 -0.100340
# 1                 -0.435681
# 2                 -0.577140
# 3                  0.365554
# 4                 -0.451945
# ...                     ...
# 5978              -0.156440
# 5979               0.654454
# 5980               0.330920
# 5981               0.513549
# 5982               0.495838
#
# [5983 rows x 9 columns]

# %%
promoters_loeuf_expressionVariation = promoters_loeuf_expressionVariation[promoters_loeuf_expressionVariation['gene_name_x'] == promoters_loeuf_expressionVariation['gene_name_y']]
promoters_loeuf_expressionVariation = promoters_loeuf_expressionVariation.drop(columns=['gene_name_x', 'gene_name_y'])
promoters_loeuf_expressionVariation
# Out:
#               gene_id  cpg_density_region_grch38  loeuf  promoter_phastcons  \
# 0     ENSG00000137936                   0.856014  0.396            0.121925
# 1     ENSG00000054267                   0.746902  0.189            0.276475
# 2     ENSG00000081019                   0.724217  0.435            0.290900
# 3     ENSG00000143502                   0.705071  0.734            0.222000
# 4     ENSG00000081026                   0.698284  0.387            0.315775
# ...               ...                        ...    ...                 ...
# 5977  ENSG00000100354                   0.352168  0.159            0.489275
# 5979  ENSG00000100097                   0.346850  1.667            0.116800
# 5980  ENSG00000235568                   0.296590  1.215            0.064800
# 5981  ENSG00000128218                   0.283518  1.885            0.076225
# 5982  ENSG00000100170                   0.177320  0.746            0.091225
#
#       N_bar_mean_neutral  K_bar_mean_neutral  mean_variation_global
# 0              -2.064132            0.999113              -0.100340
# 1              -1.400205           -1.059925              -0.435681
# 2              -0.816445           -0.293793              -0.577140
# 3              -2.608241            0.316959               0.365554
# 4              -2.727076            0.987644              -0.451945
# ...                  ...                 ...                    ...
# 5977           -0.255897            0.492825              -0.316788
# 5979           -0.314059            0.127069               0.654454
# 5980           -0.276616           -0.311553               0.330920
# 5981            0.356627           -0.324641               0.513549
# 5982           -0.978971           -0.510705               0.495838
#
# [5818 rows x 7 columns]

# %%
import seaborn as sns
sns.set(font_scale = 2)

x_vars = [
    'cpg_density_region_grch38', 
    'loeuf', 
    'promoter_phastcons', 
    'N_bar_mean_neutral', 
    'K_bar_mean_neutral'
]

sns.pairplot(
    data=promoters_loeuf_expressionVariation,
    x_vars=x_vars,
    y_vars=['mean_variation_global'],
    kind='kde',
    height=4
)
