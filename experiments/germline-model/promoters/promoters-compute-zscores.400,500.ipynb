# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import logging 

logging.basicConfig(
  format = '%(asctime)s %(message)s',
  level=logging.INFO,
  datefmt='%Y-%m-%d %H:%M:%S'
)

# %%
import pandas as pd

CONSTRAINT_TOOLS = '/scratch/ucgd/lustre-work/quinlan/u6018199/constraint-tools'
promoters_filename = f'{CONSTRAINT_TOOLS}/download-process-data/promoters/promoters.grch38.csv'
promoters = pd.read_csv(promoters_filename, sep=',')
promoters
# Out:
#          transcript_id          gene_id gene_name  cpg_density  loeuf  \
# 0      ENST00000423902  ENSG00000171316      CHD7     1.093179  0.066
# 1      ENST00000262238  ENSG00000100811       YY1     1.047433  0.194
# 2      ENST00000361752  ENSG00000112531       QKI     1.025761  0.435
# 3      ENST00000376663  ENSG00000168283      BMI1     1.006077  0.359
# 4      ENST00000375856  ENSG00000185950      IRS2     1.005353  0.297
# ...                ...              ...       ...          ...    ...
# 11049  ENST00000458043  ENSG00000165899     OTOGL     0.086759  0.877
# 11050  ENST00000356972  ENSG00000196800   SPINK14     0.086755  1.372
# 11051  ENST00000336374  ENSG00000160870    CYP3A7     0.084793  1.286
# 11052  ENST00000261172  ENSG00000083782      EPYC     0.081777  1.314
# 11053  ENST00000533357  ENSG00000158887       MPZ     0.080433  0.672
#
#        oe_lof_point_estimate  promoter_phastcons  exonic_phastcons  \
# 0                   0.028673            0.384675          0.911891
# 1                   0.000000            0.391550          0.938165
# 2                   0.168260            0.184000          0.985674
# 3                   0.114010            0.494700          0.978582
# 4                   0.114820            0.327800          0.916849
# ...                      ...                 ...               ...
# 11049               0.736330            0.093875          0.842823
# 11050               0.539280            0.025025          0.577764
# 11051               0.900330            0.015400          0.491317
# 11052               0.794420            0.156150          0.837059
# 11053               0.260040            0.155375          0.901473
#
#                    region_grch38  region_grch38_length  \
# 0         chr8:60676779-60680777                  3999
# 1      chr14:100236986-100240984                  3999
# 2       chr6:163412644-163416642                  3999
# 3        chr10:22319212-22323210                  3999
# 4      chr13:109784570-109788568                  3999
# ...                          ...                   ...
# 11049    chr12:80207454-80211452                  3999
# 11050   chr5:148167734-148171732                  3999
# 11051     chr7:99733098-99737096                  3999
# 11052    chr12:91003028-91007026                  3999
# 11053   chr1:161307974-161311972                  3999
#
#            region_grch38_clipped
# 0         chr8:60678279-60679277
# 1      chr14:100238486-100239484
# 2       chr6:163414144-163415142
# 3        chr10:22320712-22321710
# 4      chr13:109786070-109787068
# ...                          ...
# 11049    chr12:80208954-80209952
# 11050   chr5:148169234-148170232
# 11051     chr7:99734598-99735596
# 11052    chr12:91004528-91005526
# 11053   chr1:161309474-161310472
#
# [11054 rows x 11 columns]

# %%
import sys
sys.path.append('/scratch/ucgd/lustre-work/quinlan/u6018199/constraint-tools/utilities')

from pack_unpack import unpack
import pyranges as pr

def add_chromosome_start_end(row): 
    region = row['region_grch38_clipped'] 
    row['Chromosome'], row['Start'], row['End'] = unpack(region)
    return row

promoters = promoters.apply(add_chromosome_start_end, axis=1)
promoters = pr.PyRanges(promoters)
promoters
# Out:
# +-----------------+-----------------+-------------+--------------------+-------------+-------------------------+-------+
# | transcript_id   | gene_id         | gene_name   | cpg_density        | loeuf       | oe_lof_point_estimate   | +8    |
# | (object)        | (object)        | (object)    | (float64)          | (float64)   | (float64)               | ...   |
# |-----------------+-----------------+-------------+--------------------+-------------+-------------------------+-------|
# | ENST00000283179 | ENSG00000153187 | HNRNPU      | 0.9657984431329096 | 0.118       | 0.024905                | ...   |
# | ENST00000366609 | ENSG00000168264 | IRF2BP2     | 0.937473288904452  | 0.448       | 0.094388                | ...   |
# | ENST00000366813 | ENSG00000163041 | H3F3A       | 0.9025067123936734 | 1.157       | 0.36973                 | ...   |
# | ENST00000270722 | ENSG00000142611 | PRDM16      | 0.8974599596619377 | 0.185       | 0.080679                | ...   |
# | ...             | ...             | ...         | ...                | ...         | ...                     | ...   |
# | ENST00000331428 | ENSG00000172967 | XKR3        | 0.1216449877920565 | 0.945       | 0.36581                 | ...   |
# | ENST00000404699 | ENSG00000175329 | ISX         | 0.1222064937938543 | 1.7         | 0.95398                 | ...   |
# | ENST00000215812 | ENSG00000100012 | SEC14L3     | 0.146732720846501  | 1.639       | 1.2174                  | ...   |
# | ENST00000215885 | ENSG00000100078 | PLA2G3      | 0.1603102153903856 | 1.186       | 0.80805                 | ...   |
# | ENST00000248935 | ENSG00000184674 | GSTT1       | 0.3270440251572327 | 1.37        | 0.73203                 | ...   |
# | ENST00000379442 | ENSG00000205277 | MUC12       | 0.2545709674080151 | 1.432       | 1.1946                  | ...   |
# +-----------------+-----------------+-------------+--------------------+-------------+-------------------------+-------+
# Unstranded PyRanges object has 11,054 rows and 14 columns from 25 chromosomes.
# For printing, the PyRanges was sorted on Chromosome.
# 8 hidden columns: promoter_phastcons, exonic_phastcons, region_grch38, region_grch38_length, region_grch38_clipped, Chromosome, ... (+ 2 more.)

# %%
from read_model import read_model 

model = read_model('/scratch/ucgd/lustre-work/quinlan/u6018199/constraint-tools/dist/model-germline-grch38.json')

# https://biocore-ntnu.github.io/pyranges/loadingcreating-pyranges.html
neutral_regions = pr.read_bed(model['neutralRegions'])

neutral_regions
# Out:
# +--------------+-----------+-----------+
# | Chromosome   | Start     | End       |
# | (category)   | (int32)   | (int32)   |
# |--------------+-----------+-----------|
# | chr1         | 14653     | 14905     |
# | chr1         | 15354     | 15772     |
# | chr1         | 16125     | 16607     |
# | chr1         | 17055     | 17171     |
# | ...          | ...       | ...       |
# | chr22        | 50796386  | 50796692  |
# | chr22        | 50796780  | 50796942  |
# | chr22        | 50797586  | 50797812  |
# | chr22        | 50798276  | 50798655  |
# +--------------+-----------+-----------+
# Unstranded PyRanges object has 1,649,459 rows and 3 columns from 22 chromosomes.
# For printing, the PyRanges was sorted on Chromosome.

# %%
promoters.promoter_id = promoters.df.index.values

promoters
# Out:
# +-----------------+-----------------+-------------+--------------------+-------------+-------------------------+-------+
# | transcript_id   | gene_id         | gene_name   | cpg_density        | loeuf       | oe_lof_point_estimate   | +9    |
# | (object)        | (object)        | (object)    | (float64)          | (float64)   | (float64)               | ...   |
# |-----------------+-----------------+-------------+--------------------+-------------+-------------------------+-------|
# | ENST00000283179 | ENSG00000153187 | HNRNPU      | 0.9657984431329096 | 0.118       | 0.024905                | ...   |
# | ENST00000366609 | ENSG00000168264 | IRF2BP2     | 0.937473288904452  | 0.448       | 0.094388                | ...   |
# | ENST00000366813 | ENSG00000163041 | H3F3A       | 0.9025067123936734 | 1.157       | 0.36973                 | ...   |
# | ENST00000270722 | ENSG00000142611 | PRDM16      | 0.8974599596619377 | 0.185       | 0.080679                | ...   |
# | ...             | ...             | ...         | ...                | ...         | ...                     | ...   |
# | ENST00000331428 | ENSG00000172967 | XKR3        | 0.1216449877920565 | 0.945       | 0.36581                 | ...   |
# | ENST00000404699 | ENSG00000175329 | ISX         | 0.1222064937938543 | 1.7         | 0.95398                 | ...   |
# | ENST00000215812 | ENSG00000100012 | SEC14L3     | 0.146732720846501  | 1.639       | 1.2174                  | ...   |
# | ENST00000215885 | ENSG00000100078 | PLA2G3      | 0.1603102153903856 | 1.186       | 0.80805                 | ...   |
# | ENST00000248935 | ENSG00000184674 | GSTT1       | 0.3270440251572327 | 1.37        | 0.73203                 | ...   |
# | ENST00000379442 | ENSG00000205277 | MUC12       | 0.2545709674080151 | 1.432       | 1.1946                  | ...   |
# +-----------------+-----------------+-------------+--------------------+-------------+-------------------------+-------+
# Unstranded PyRanges object has 11,054 rows and 15 columns from 25 chromosomes.
# For printing, the PyRanges was sorted on Chromosome.
# 9 hidden columns: promoter_phastcons, exonic_phastcons, region_grch38, region_grch38_length, region_grch38_clipped, Chromosome, ... (+ 3 more.)

# %%
# https://pyranges.readthedocs.io/en/latest/autoapi/pyranges/pyranges/index.html?highlight=intersect#pyranges.pyranges.PyRanges.overlap

promoters_that_overlap_neutral_regions = promoters.overlap(neutral_regions).df
promoters_that_overlap_neutral_regions
# Out:
#          transcript_id          gene_id gene_name  cpg_density  loeuf  \
# 0      ENST00000283179  ENSG00000153187    HNRNPU     0.965798  0.118
# 1      ENST00000366813  ENSG00000163041     H3F3A     0.902507  1.157
# 2      ENST00000270722  ENSG00000142611    PRDM16     0.897460  0.185
# 3      ENST00000370445  ENSG00000143032    BARHL2     0.896027  0.547
# 4      ENST00000312239  ENSG00000127483    HP1BP3     0.893127  0.306
# ...                ...              ...       ...          ...    ...
# 10388  ENST00000266088  ENSG00000100170    SLC5A1     0.177320  0.746
# 10389  ENST00000215885  ENSG00000100078    PLA2G3     0.160310  1.186
# 10390  ENST00000215812  ENSG00000100012   SEC14L3     0.146733  1.639
# 10391  ENST00000404699  ENSG00000175329       ISX     0.122206  1.700
# 10392  ENST00000331428  ENSG00000172967      XKR3     0.121645  0.945
#
#        oe_lof_point_estimate  promoter_phastcons  exonic_phastcons  \
# 0                   0.024905            0.343500          0.968901
# 1                   0.369730            0.364550          0.977616
# 2                   0.080679            0.314425          0.911041
# 3                   0.173920            0.471100          0.931959
# 4                   0.118370            0.133375          0.890274
# ...                      ...                 ...               ...
# 10388               0.497440            0.091225          0.830670
# 10389               0.808050            0.137300          0.543476
# 10390               1.217400            0.099950          0.878042
# 10391               0.953980            0.046275          0.530358
# 10392               0.365810            0.281825          0.653140
#
#                   region_grch38  region_grch38_length  \
# 0      chr1:244862473-244866471                  3999
# 1      chr1:226061978-226065976                  3999
# 2          chr1:3067212-3071210                  3999
# 3        chr1:90715239-90719237                  3999
# 4        chr1:20784690-20788688                  3999
# ...                         ...                   ...
# 10388   chr22:32041033-32045031                  3999
# 10389   chr22:31138609-31142607                  3999
# 10390   chr22:30470051-30474049                  3999
# 10391   chr22:35064137-35068135                  3999
# 10392   chr22:16819701-16823699                  3999
#
#           region_grch38_clipped Chromosome      Start        End  promoter_id
# 0      chr1:244863973-244864971       chr1  244863973  244864971            0
# 1      chr1:226063478-226064476       chr1  226063478  226064476            2
# 2          chr1:3068712-3069710       chr1    3068712    3069710            3
# 3        chr1:90716739-90717737       chr1   90716739   90717737            4
# 4        chr1:20786190-20787188       chr1   20786190   20787188            5
# ...                         ...        ...        ...        ...          ...
# 10388   chr22:32042533-32043531      chr22   32042533   32043531        11047
# 10389   chr22:31140109-31141107      chr22   31140109   31141107        11048
# 10390   chr22:30471551-30472549      chr22   30471551   30472549        11049
# 10391   chr22:35065637-35066635      chr22   35065637   35066635        11050
# 10392   chr22:16821201-16822199      chr22   16821201   16822199        11051
#
# [10393 rows x 15 columns]

# %%
# https://pyranges.readthedocs.io/en/latest/autoapi/pyranges/pyranges/index.html?highlight=intersect#pyranges.pyranges.PyRanges.intersect

neutral_regions_within_promoters = promoters.intersect(neutral_regions).df[['Start', 'End', 'promoter_id']]
neutral_regions_within_promoters
# Out:
#            Start        End  promoter_id
# 0      244864560  244864738            0
# 1      226063681  226063880            2
# 2        3068712    3068866            3
# 3        3069296    3069710            3
# 4       90717302   90717737            4
# ...          ...        ...          ...
# 19916   30471551   30471905        11049
# 19917   30472017   30472549        11049
# 19918   35065637   35066136        11050
# 19919   16821201   16821525        11051
# 19920   16821699   16822199        11051
#
# [19921 rows x 3 columns]

# %%
promoters_with_neutral_regions = pd.merge(
  promoters_that_overlap_neutral_regions, 
  neutral_regions_within_promoters,
  on='promoter_id', 
  how='inner'
)
promoters_with_neutral_regions = promoters_with_neutral_regions.rename(columns={
  "Start_x": "Start_promoter", 
  "End_x": "End_promoter",
  "Start_y": "Start_neutral_part", 
  "End_y": "End_neutral_part",
})
promoters_with_neutral_regions
# Out:
#          transcript_id          gene_id gene_name  cpg_density  loeuf  \
# 0      ENST00000283179  ENSG00000153187    HNRNPU     0.965798  0.118
# 1      ENST00000366813  ENSG00000163041     H3F3A     0.902507  1.157
# 2      ENST00000270722  ENSG00000142611    PRDM16     0.897460  0.185
# 3      ENST00000270722  ENSG00000142611    PRDM16     0.897460  0.185
# 4      ENST00000370445  ENSG00000143032    BARHL2     0.896027  0.547
# ...                ...              ...       ...          ...    ...
# 19916  ENST00000215812  ENSG00000100012   SEC14L3     0.146733  1.639
# 19917  ENST00000215812  ENSG00000100012   SEC14L3     0.146733  1.639
# 19918  ENST00000404699  ENSG00000175329       ISX     0.122206  1.700
# 19919  ENST00000331428  ENSG00000172967      XKR3     0.121645  0.945
# 19920  ENST00000331428  ENSG00000172967      XKR3     0.121645  0.945
#
#        oe_lof_point_estimate  promoter_phastcons  exonic_phastcons  \
# 0                   0.024905            0.343500          0.968901
# 1                   0.369730            0.364550          0.977616
# 2                   0.080679            0.314425          0.911041
# 3                   0.080679            0.314425          0.911041
# 4                   0.173920            0.471100          0.931959
# ...                      ...                 ...               ...
# 19916               1.217400            0.099950          0.878042
# 19917               1.217400            0.099950          0.878042
# 19918               0.953980            0.046275          0.530358
# 19919               0.365810            0.281825          0.653140
# 19920               0.365810            0.281825          0.653140
#
#                   region_grch38  region_grch38_length  \
# 0      chr1:244862473-244866471                  3999
# 1      chr1:226061978-226065976                  3999
# 2          chr1:3067212-3071210                  3999
# 3          chr1:3067212-3071210                  3999
# 4        chr1:90715239-90719237                  3999
# ...                         ...                   ...
# 19916   chr22:30470051-30474049                  3999
# 19917   chr22:30470051-30474049                  3999
# 19918   chr22:35064137-35068135                  3999
# 19919   chr22:16819701-16823699                  3999
# 19920   chr22:16819701-16823699                  3999
#
#           region_grch38_clipped Chromosome  Start_promoter  End_promoter  \
# 0      chr1:244863973-244864971       chr1       244863973     244864971
# 1      chr1:226063478-226064476       chr1       226063478     226064476
# 2          chr1:3068712-3069710       chr1         3068712       3069710
# 3          chr1:3068712-3069710       chr1         3068712       3069710
# 4        chr1:90716739-90717737       chr1        90716739      90717737
# ...                         ...        ...             ...           ...
# 19916   chr22:30471551-30472549      chr22        30471551      30472549
# 19917   chr22:30471551-30472549      chr22        30471551      30472549
# 19918   chr22:35065637-35066635      chr22        35065637      35066635
# 19919   chr22:16821201-16822199      chr22        16821201      16822199
# 19920   chr22:16821201-16822199      chr22        16821201      16822199
#
#        promoter_id  Start_neutral_part  End_neutral_part
# 0                0           244864560         244864738
# 1                2           226063681         226063880
# 2                3             3068712           3068866
# 3                3             3069296           3069710
# 4                4            90717302          90717737
# ...            ...                 ...               ...
# 19916        11049            30471551          30471905
# 19917        11049            30472017          30472549
# 19918        11050            35065637          35066136
# 19919        11051            16821201          16821525
# 19920        11051            16821699          16822199
#
# [19921 rows x 17 columns]

# %%
def compute_neutral_part_length(row):
    return row['End_neutral_part'] - row['Start_neutral_part']

promoters_with_neutral_regions['neutral_part_length'] = promoters_with_neutral_regions.apply(compute_neutral_part_length, axis=1)
promoters_with_neutral_regions
# Out:
#          transcript_id          gene_id gene_name  cpg_density  loeuf  \
# 0      ENST00000283179  ENSG00000153187    HNRNPU     0.965798  0.118
# 1      ENST00000366813  ENSG00000163041     H3F3A     0.902507  1.157
# 2      ENST00000270722  ENSG00000142611    PRDM16     0.897460  0.185
# 3      ENST00000270722  ENSG00000142611    PRDM16     0.897460  0.185
# 4      ENST00000370445  ENSG00000143032    BARHL2     0.896027  0.547
# ...                ...              ...       ...          ...    ...
# 19916  ENST00000215812  ENSG00000100012   SEC14L3     0.146733  1.639
# 19917  ENST00000215812  ENSG00000100012   SEC14L3     0.146733  1.639
# 19918  ENST00000404699  ENSG00000175329       ISX     0.122206  1.700
# 19919  ENST00000331428  ENSG00000172967      XKR3     0.121645  0.945
# 19920  ENST00000331428  ENSG00000172967      XKR3     0.121645  0.945
#
#        oe_lof_point_estimate  promoter_phastcons  exonic_phastcons  \
# 0                   0.024905            0.343500          0.968901
# 1                   0.369730            0.364550          0.977616
# 2                   0.080679            0.314425          0.911041
# 3                   0.080679            0.314425          0.911041
# 4                   0.173920            0.471100          0.931959
# ...                      ...                 ...               ...
# 19916               1.217400            0.099950          0.878042
# 19917               1.217400            0.099950          0.878042
# 19918               0.953980            0.046275          0.530358
# 19919               0.365810            0.281825          0.653140
# 19920               0.365810            0.281825          0.653140
#
#                   region_grch38  region_grch38_length  \
# 0      chr1:244862473-244866471                  3999
# 1      chr1:226061978-226065976                  3999
# 2          chr1:3067212-3071210                  3999
# 3          chr1:3067212-3071210                  3999
# 4        chr1:90715239-90719237                  3999
# ...                         ...                   ...
# 19916   chr22:30470051-30474049                  3999
# 19917   chr22:30470051-30474049                  3999
# 19918   chr22:35064137-35068135                  3999
# 19919   chr22:16819701-16823699                  3999
# 19920   chr22:16819701-16823699                  3999
#
#           region_grch38_clipped Chromosome  Start_promoter  End_promoter  \
# 0      chr1:244863973-244864971       chr1       244863973     244864971
# 1      chr1:226063478-226064476       chr1       226063478     226064476
# 2          chr1:3068712-3069710       chr1         3068712       3069710
# 3          chr1:3068712-3069710       chr1         3068712       3069710
# 4        chr1:90716739-90717737       chr1        90716739      90717737
# ...                         ...        ...             ...           ...
# 19916   chr22:30471551-30472549      chr22        30471551      30472549
# 19917   chr22:30471551-30472549      chr22        30471551      30472549
# 19918   chr22:35065637-35066635      chr22        35065637      35066635
# 19919   chr22:16821201-16822199      chr22        16821201      16822199
# 19920   chr22:16821201-16822199      chr22        16821201      16822199
#
#        promoter_id  Start_neutral_part  End_neutral_part  neutral_part_length
# 0                0           244864560         244864738                  178
# 1                2           226063681         226063880                  199
# 2                3             3068712           3068866                  154
# 3                3             3069296           3069710                  414
# 4                4            90717302          90717737                  435
# ...            ...                 ...               ...                  ...
# 19916        11049            30471551          30471905                  354
# 19917        11049            30472017          30472549                  532
# 19918        11050            35065637          35066136                  499
# 19919        11051            16821201          16821525                  324
# 19920        11051            16821699          16822199                  500
#
# [19921 rows x 18 columns]

# %%
promoters_with_neutral_regions = promoters_with_neutral_regions[['promoter_id', 'neutral_part_length']]
promoters_with_neutral_regions
# Out:
#        promoter_id  neutral_part_length
# 0                0                  178
# 1                2                  199
# 2                3                  154
# 3                3                  414
# 4                4                  435
# ...            ...                  ...
# 19916        11049                  354
# 19917        11049                  532
# 19918        11050                  499
# 19919        11051                  324
# 19920        11051                  500
#
# [19921 rows x 2 columns]

# %%
grouped_neutral_regions = promoters_with_neutral_regions.groupby('promoter_id')

number_neutral_bases = grouped_neutral_regions['neutral_part_length'].sum().rename("number_neutral_bases")
number_neutral_bases
# Out:
# promoter_id
# 0        178
# 2        199
# 3        568
# 4        435
# 5        522
#         ...
# 11047    843
# 11048    599
# 11049    886
# 11050    499
# 11051    824
# Name: number_neutral_bases, Length: 10393, dtype: int64

# %%
number_neutral_parts = grouped_neutral_regions['neutral_part_length'].count().rename('number_neutral_parts')
number_neutral_parts
# Out:
# promoter_id
# 0        1
# 2        1
# 3        2
# 4        1
# 5        1
#         ..
# 11047    2
# 11048    1
# 11049    2
# 11050    1
# 11051    2
# Name: number_neutral_parts, Length: 10393, dtype: int64

# %%
promoters = ( 
  promoters.df
  .merge(number_neutral_bases, on='promoter_id', how='inner')
  .merge(number_neutral_parts, on='promoter_id', how='inner')
)

promoters
# Out:
#          transcript_id          gene_id gene_name  cpg_density  loeuf  \
# 0      ENST00000283179  ENSG00000153187    HNRNPU     0.965798  0.118
# 1      ENST00000366813  ENSG00000163041     H3F3A     0.902507  1.157
# 2      ENST00000270722  ENSG00000142611    PRDM16     0.897460  0.185
# 3      ENST00000370445  ENSG00000143032    BARHL2     0.896027  0.547
# 4      ENST00000312239  ENSG00000127483    HP1BP3     0.893127  0.306
# ...                ...              ...       ...          ...    ...
# 10388  ENST00000266088  ENSG00000100170    SLC5A1     0.177320  0.746
# 10389  ENST00000215885  ENSG00000100078    PLA2G3     0.160310  1.186
# 10390  ENST00000215812  ENSG00000100012   SEC14L3     0.146733  1.639
# 10391  ENST00000404699  ENSG00000175329       ISX     0.122206  1.700
# 10392  ENST00000331428  ENSG00000172967      XKR3     0.121645  0.945
#
#        oe_lof_point_estimate  promoter_phastcons  exonic_phastcons  \
# 0                   0.024905            0.343500          0.968901
# 1                   0.369730            0.364550          0.977616
# 2                   0.080679            0.314425          0.911041
# 3                   0.173920            0.471100          0.931959
# 4                   0.118370            0.133375          0.890274
# ...                      ...                 ...               ...
# 10388               0.497440            0.091225          0.830670
# 10389               0.808050            0.137300          0.543476
# 10390               1.217400            0.099950          0.878042
# 10391               0.953980            0.046275          0.530358
# 10392               0.365810            0.281825          0.653140
#
#                   region_grch38  region_grch38_length  \
# 0      chr1:244862473-244866471                  3999
# 1      chr1:226061978-226065976                  3999
# 2          chr1:3067212-3071210                  3999
# 3        chr1:90715239-90719237                  3999
# 4        chr1:20784690-20788688                  3999
# ...                         ...                   ...
# 10388   chr22:32041033-32045031                  3999
# 10389   chr22:31138609-31142607                  3999
# 10390   chr22:30470051-30474049                  3999
# 10391   chr22:35064137-35068135                  3999
# 10392   chr22:16819701-16823699                  3999
#
#           region_grch38_clipped Chromosome      Start        End  promoter_id  \
# 0      chr1:244863973-244864971       chr1  244863973  244864971            0
# 1      chr1:226063478-226064476       chr1  226063478  226064476            2
# 2          chr1:3068712-3069710       chr1    3068712    3069710            3
# 3        chr1:90716739-90717737       chr1   90716739   90717737            4
# 4        chr1:20786190-20787188       chr1   20786190   20787188            5
# ...                         ...        ...        ...        ...          ...
# 10388   chr22:32042533-32043531      chr22   32042533   32043531        11047
# 10389   chr22:31140109-31141107      chr22   31140109   31141107        11048
# 10390   chr22:30471551-30472549      chr22   30471551   30472549        11049
# 10391   chr22:35065637-35066635      chr22   35065637   35066635        11050
# 10392   chr22:16821201-16822199      chr22   16821201   16822199        11051
#
#        number_neutral_bases  number_neutral_parts
# 0                       178                     1
# 1                       199                     1
# 2                       568                     2
# 3                       435                     1
# 4                       522                     1
# ...                     ...                   ...
# 10388                   843                     2
# 10389                   599                     1
# 10390                   886                     2
# 10391                   499                     1
# 10392                   824                     2
#
# [10393 rows x 17 columns]

# %%
promoters['number_neutral_bases'].hist()
# Out:
# <AxesSubplot:>

# %%
# https://papermill.readthedocs.io/en/latest/usage-parameterize.html
number_neutral_bases_lower = None
number_neutral_bases_upper = None

# %%
# Parameters
number_neutral_bases_lower = 400
number_neutral_bases_upper = 500

# %%
# https://pandas.pydata.org/pandas-docs/stable/getting_started/intro_tutorials/03_subset_data.html#how-do-i-filter-specific-rows-from-a-dataframe
promoters = promoters[
    (promoters['number_neutral_bases'] > number_neutral_bases_lower) & 
    (promoters['number_neutral_bases'] < number_neutral_bases_upper) & 
    (promoters['number_neutral_parts'] < 5)
]
promoters
# Out:
#          transcript_id          gene_id gene_name  cpg_density  loeuf  \
# 3      ENST00000370445  ENSG00000143032    BARHL2     0.896027  0.547
# 13     ENST00000407071  ENSG00000162849    KIF26B     0.831528  0.214
# 14     ENST00000040877  ENSG00000059588    TARBP1     0.828901  0.811
# 27     ENST00000369784  ENSG00000162775     RBM15     0.798255  0.271
# 45     ENST00000368480  ENSG00000163239    TDRD10     0.771822  0.937
# ...                ...              ...       ...          ...    ...
# 10364  ENST00000505920  ENSG00000249222    ATP5L2     0.356299  1.961
# 10373  ENST00000399167  ENSG00000183773     AIFM3     0.325283  0.985
# 10383  ENST00000317749  ENSG00000189269  C22orf43     0.229686  1.704
# 10386  ENST00000397326  ENSG00000198125        MB     0.221175  1.326
# 10391  ENST00000404699  ENSG00000175329       ISX     0.122206  1.700
#
#        oe_lof_point_estimate  promoter_phastcons  exonic_phastcons  \
# 3                    0.17392            0.471100          0.931959
# 13                   0.11385            0.358200          0.769354
# 14                   0.63420            0.116225          0.671640
# 27                   0.11861            0.360725          0.821268
# 45                   0.56614            0.152075          0.218256
# ...                      ...                 ...               ...
# 10364                2.53550            0.168750          0.338390
# 10373                0.71418            0.035225          0.876389
# 10383                1.22370            0.030900          0.002032
# 10386                0.51911            0.076875          0.933319
# 10391                0.95398            0.046275          0.530358
#
#                   region_grch38  region_grch38_length  \
# 3        chr1:90715239-90719237                  3999
# 13     chr1:245152986-245156984                  3999
# 14     chr1:234477105-234481103                  3999
# 27     chr1:110336507-110340505                  3999
# 45     chr1:154500973-154504971                  3999
# ...                         ...                   ...
# 10364   chr22:42638603-42642601                  3999
# 10373   chr22:20963109-20967107                  3999
# 10383   chr22:23630323-23634321                  3999
# 10386   chr22:35615458-35619456                  3999
# 10391   chr22:35064137-35068135                  3999
#
#           region_grch38_clipped Chromosome      Start        End  promoter_id  \
# 3        chr1:90716739-90717737       chr1   90716739   90717737            4
# 13     chr1:245154486-245155484       chr1  245154486  245155484           15
# 14     chr1:234478605-234479603       chr1  234478605  234479603           16
# 27     chr1:110338007-110339005       chr1  110338007  110339005           31
# 45     chr1:154502473-154503471       chr1  154502473  154503471           51
# ...                         ...        ...        ...        ...          ...
# 10364   chr22:42640103-42641101      chr22   42640103   42641101        11021
# 10373   chr22:20964609-20965607      chr22   20964609   20965607        11030
# 10383   chr22:23631823-23632821      chr22   23631823   23632821        11040
# 10386   chr22:35616958-35617956      chr22   35616958   35617956        11043
# 10391   chr22:35065637-35066635      chr22   35065637   35066635        11050
#
#        number_neutral_bases  number_neutral_parts
# 3                       435                     1
# 13                      499                     1
# 14                      424                     1
# 27                      454                     1
# 45                      442                     1
# ...                     ...                   ...
# 10364                   487                     2
# 10373                   490                     2
# 10383                   463                     2
# 10386                   489                     2
# 10391                   499                     1
#
# [1780 rows x 17 columns]

# %%
#papermill_description=COMPUTE_ZSCORES

import numpy as np 

sys.path.append('/scratch/ucgd/lustre-work/quinlan/u6018199/constraint-tools/predict-constraint/germline-model')
from expected_observed_counts import compute_expected_observed_counts
from pack_unpack import pack

window_stride = 10 

def filter_and_average(xs): 
    if not xs: return None 
    elif len(xs) == 0: return None
    else: return np.mean([x for x in xs if x])

def compute_neutral_zscores(row): 
    region = pack(row['Chromosome'], row['Start'], row['End'])  
    expected_observed_counts = compute_expected_observed_counts(region, model, window_stride, log=False) 
    # https://www.dataquest.io/blog/settingwithcopywarning/
    with pd.option_context('mode.chained_assignment', None):
        row['N_bar_mean_neutral'] = filter_and_average(expected_observed_counts['NBarsNeutralRegions'])
        row['N_observeds_mean_neutral'] = filter_and_average(expected_observed_counts['NObservedsNeutralRegions'])
        row['K_bar_mean_neutral'] = filter_and_average(expected_observed_counts['KBarsNeutralRegions'])
        row['K_observeds_mean_neutral'] = filter_and_average(expected_observed_counts['KObservedsNeutralRegions'])
    return row 

# https://stackoverflow.com/a/34365537/6674256
from tqdm.auto import tqdm  # for notebooks
tqdm.pandas()
logging.info('Computing z-scores for promoters...')
promoters_with_zscores = promoters.progress_apply(compute_neutral_zscores, axis=1)
logging.info('...finished computing z-scores for promoters...')

promoters_with_zscores.head()
# Out:
# 2022-06-09 12:24:23 Computing z-scores for promoters...
#   0%|          | 0/1780 [00:00<?, ?it/s]
# 2022-06-09 14:10:12 ...finished computing z-scores for promoters...
#       transcript_id          gene_id gene_name  cpg_density  loeuf  \
# 3   ENST00000370445  ENSG00000143032    BARHL2     0.896027  0.547
# 13  ENST00000407071  ENSG00000162849    KIF26B     0.831528  0.214
# 14  ENST00000040877  ENSG00000059588    TARBP1     0.828901  0.811
# 27  ENST00000369784  ENSG00000162775     RBM15     0.798255  0.271
# 45  ENST00000368480  ENSG00000163239    TDRD10     0.771822  0.937
#
#     oe_lof_point_estimate  promoter_phastcons  exonic_phastcons  \
# 3                 0.17392            0.471100          0.931959
# 13                0.11385            0.358200          0.769354
# 14                0.63420            0.116225          0.671640
# 27                0.11861            0.360725          0.821268
# 45                0.56614            0.152075          0.218256
#
#                region_grch38  region_grch38_length  ... Chromosome      Start  \
# 3     chr1:90715239-90719237                  3999  ...       chr1   90716739
# 13  chr1:245152986-245156984                  3999  ...       chr1  245154486
# 14  chr1:234477105-234481103                  3999  ...       chr1  234478605
# 27  chr1:110336507-110340505                  3999  ...       chr1  110338007
# 45  chr1:154500973-154504971                  3999  ...       chr1  154502473
#
#           End  promoter_id  number_neutral_bases  number_neutral_parts  \
# 3    90717737            4                   435                     1
# 13  245155484           15                   499                     1
# 14  234479603           16                   424                     1
# 27  110339005           31                   454                     1
# 45  154503471           51                   442                     1
#
#     N_bar_mean_neutral  N_observeds_mean_neutral  K_bar_mean_neutral  \
# 3            -2.094556                 25.878788           -0.140948
# 13           -1.809684                 31.200000            1.068934
# 14            0.323185                 23.500000            0.625223
# 27           -0.295771                 28.416667            0.410839
# 45           -0.785943                 26.411765            0.267585
#
#     K_observeds_mean_neutral
# 3                  12.939394
# 13                 18.775000
# 14                 13.625000
# 27                 15.472222
# 45                 14.117647
#
# [5 rows x 21 columns]

# %%
promoters_with_zscores = promoters_with_zscores.rename(columns={'cpg_density': 'cpg_density_region_grch38'})
promoters_with_zscores
# Out:
#          transcript_id          gene_id gene_name  cpg_density_region_grch38  \
# 3      ENST00000370445  ENSG00000143032    BARHL2                   0.896027
# 13     ENST00000407071  ENSG00000162849    KIF26B                   0.831528
# 14     ENST00000040877  ENSG00000059588    TARBP1                   0.828901
# 27     ENST00000369784  ENSG00000162775     RBM15                   0.798255
# 45     ENST00000368480  ENSG00000163239    TDRD10                   0.771822
# ...                ...              ...       ...                        ...
# 10364  ENST00000505920  ENSG00000249222    ATP5L2                   0.356299
# 10373  ENST00000399167  ENSG00000183773     AIFM3                   0.325283
# 10383  ENST00000317749  ENSG00000189269  C22orf43                   0.229686
# 10386  ENST00000397326  ENSG00000198125        MB                   0.221175
# 10391  ENST00000404699  ENSG00000175329       ISX                   0.122206
#
#        loeuf  oe_lof_point_estimate  promoter_phastcons  exonic_phastcons  \
# 3      0.547                0.17392            0.471100          0.931959
# 13     0.214                0.11385            0.358200          0.769354
# 14     0.811                0.63420            0.116225          0.671640
# 27     0.271                0.11861            0.360725          0.821268
# 45     0.937                0.56614            0.152075          0.218256
# ...      ...                    ...                 ...               ...
# 10364  1.961                2.53550            0.168750          0.338390
# 10373  0.985                0.71418            0.035225          0.876389
# 10383  1.704                1.22370            0.030900          0.002032
# 10386  1.326                0.51911            0.076875          0.933319
# 10391  1.700                0.95398            0.046275          0.530358
#
#                   region_grch38  region_grch38_length  ... Chromosome  \
# 3        chr1:90715239-90719237                  3999  ...       chr1
# 13     chr1:245152986-245156984                  3999  ...       chr1
# 14     chr1:234477105-234481103                  3999  ...       chr1
# 27     chr1:110336507-110340505                  3999  ...       chr1
# 45     chr1:154500973-154504971                  3999  ...       chr1
# ...                         ...                   ...  ...        ...
# 10364   chr22:42638603-42642601                  3999  ...      chr22
# 10373   chr22:20963109-20967107                  3999  ...      chr22
# 10383   chr22:23630323-23634321                  3999  ...      chr22
# 10386   chr22:35615458-35619456                  3999  ...      chr22
# 10391   chr22:35064137-35068135                  3999  ...      chr22
#
#            Start        End  promoter_id  number_neutral_bases  \
# 3       90716739   90717737            4                   435
# 13     245154486  245155484           15                   499
# 14     234478605  234479603           16                   424
# 27     110338007  110339005           31                   454
# 45     154502473  154503471           51                   442
# ...          ...        ...          ...                   ...
# 10364   42640103   42641101        11021                   487
# 10373   20964609   20965607        11030                   490
# 10383   23631823   23632821        11040                   463
# 10386   35616958   35617956        11043                   489
# 10391   35065637   35066635        11050                   499
#
#        number_neutral_parts  N_bar_mean_neutral  N_observeds_mean_neutral  \
# 3                         1           -2.094556                 25.878788
# 13                        1           -1.809684                 31.200000
# 14                        1            0.323185                 23.500000
# 27                        1           -0.295771                 28.416667
# 45                        1           -0.785943                 26.411765
# ...                     ...                 ...                       ...
# 10364                     2            0.025791                 20.862069
# 10373                     2           -1.331233                 20.310345
# 10383                     2            0.618258                 24.444444
# 10386                     2            0.270705                 23.172414
# 10391                     1           -0.045763                 18.950000
#
#        K_bar_mean_neutral  K_observeds_mean_neutral
# 3               -0.140948                 12.939394
# 13               1.068934                 18.775000
# 14               0.625223                 13.625000
# 27               0.410839                 15.472222
# 45               0.267585                 14.117647
# ...                   ...                       ...
# 10364           -0.824305                  9.103448
# 10373            0.829483                 12.724138
# 10383           -0.964442                  9.851852
# 10386           -0.233797                 11.517241
# 10391           -0.692955                  8.550000
#
# [1780 rows x 21 columns]

# %%
CONSTRAINT_TOOLS_DATA = '/scratch/ucgd/lustre-work/quinlan/data-shared/constraint-tools'
promoters_with_zscores_path = (
    f'{CONSTRAINT_TOOLS_DATA}/promoters/grch38/'
    f'promoters-with-zscores.{number_neutral_bases_lower}-{number_neutral_bases_upper}.bed'
)

promoters_with_zscores.to_csv(promoters_with_zscores_path, index=False, sep='\t')
